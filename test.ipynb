# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.DataFrame(pd.read_csv('./game_crawling/pc_202004_2.csv'))

# %%
df1
# Out:
#     column-1 column-1 2       column-2  \
# 0          1        (-)      리그 오브 레전드
# 1          2        (-)         메이플스토리
# 2          3        (-)         피파온라인4
# 3          4        (-)         배틀그라운드
# 4          5        (-)           서든어택
# 5          6        (-)         마인크래프트
# 6          7        (-)         던전앤파이터
# 7          8        (-)          카트라이더
# 8          9        (-)           오버워치
# 9         10        (-)          로스트아크
# 10        11        (-)          아키에이지
# 11        12        (-)       천하제일상 거상
# 12        13        (-)          테일즈런너
# 13        14        (-)           사이퍼즈
# 14        15       (+2)            리니지
# 15        16       (-1)      패스 오브 엑자일
# 16        17       (-1)           검은사막
# 17        18        (-)  크레이지 아케이드 비엔비
# 18        19        (-)        블레이드앤소울
# 19        20       (+1)     아이온: 영원의 탑
# 20        21       (-1)  스타크래프트: 브루드 워
# 21        22        (-)    월드 오브 워크래프트
# 22        23       (+1)          바람의나라
# ...

# %%
#1


df_pic
df_pic_all
df_pic_all -> drop
#2
df_nonpic
df_nonpic_all
df_nonpic_all -> drop

#3
df_all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\haknyan\Documents\debbu\gameData\test.ipynb 셀 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/haknyan/Documents/debbu/gameData/test.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df_pic
#
# NameError: name 'df_pic' is not defined

# %%
df2 = pd.DataFrame(pd.read_csv('./game_crawling/mobile_202204_2.csv'))

# %%
df2
# Out:
#     column-1 column-1 2            column-2  \
# 0          1        (-)          던전앤파이터 모바일
# 1          2        (-)              ROBLOX
# 2          3        (-)                리니지M
# 3          4        (-)                리니지W
# 4          5        (-)         오딘: 발할라 라이징
# 5          6        (-)                언디셈버
# 6          7       (+1)             바람의나라 연
# 7          8       (-1)                  원신
# 8          9        (-)               리니지2M
# 9         10        (-)             쿠키런: 킹덤
# 10        11        (-)            전략적 팀 전투
# 11        12       (+3)       넷마블 프로야구 2022
# 12        13        (-)               브롤스타즈
# 13        14        (-)              제2의 나라
# 14        15       (+1)                포켓몬고
# 15        16       (-4)               뮤오리진3
# 16        17       (+2)              피파 모바일
# 17        18        (-)            히어로즈 테일즈
# 18        19       (-2)            검은사막 모바일
# 19        20      (NEW)          컴투스프로야구V22
# ...

# %%
df2 = pd.DataFrame(pd.read_csv('./game_crawling/pc_201901_2.csv'))

# %%
df2
# Out:
#     column-1 column-1 2                                    column-2 href  \
# 0          1        (-)               https://trees.gamemeca.com/lostark
# 1          2        (-)       https://trees.gamemeca.com/leagueoflegends
# 2          3       (+1)            https://trees.gamemeca.com/maplestory
# 3          4       (-1)           https://trees.gamemeca.com/fifaonline4
# 4          5        (-)             https://trees.gamemeca.com/kartrider
# 5          6        (-)          https://trees.gamemeca.com/battleground
# 6          7        (-)                    https://trees.gamemeca.com/df
# 7          8       (+1)          https://trees.gamemeca.com/suddenattack
# 8          9       (+1)         https://trees.gamemeca.com/playoverwatch
# 9         10       (+1)               https://trees.gamemeca.com/gersang
# 10        11       (+1)             https://trees.gamemeca.com/lineageon
# 11        12       (+2)             https://trees.gamemeca.com/minecraft
# ...

# %%
df1.drop(['column-2 href'], axis=1, inplace=True)

# %%
df.drop(['column-2 href', 'rankimg src'], axis=1, inplace=True)

# %%
df
# Out:
#     column-1 column-1 2           column-3                     column-4  \
# 0          1        (-)         A3: 스틸얼라이브                    Netmarble
# 1          2        (-)           전략적 팀 전투              Riot Games, Inc
# 2          3        (-)              리니지2M           NCSOFT Corporation
# 3          4       (+1)             ROBLOX           Roblox Corporation
# 4          5      (NEW)            블레스 모바일                JOYCITY Corp.
# 5          6       (+2)             좀비고등학교                 AWESOMEPIECE
# 6          7        (-)              브롤스타즈                    Supercell
# 7          8       (-2)            AFK 아레나                 Lilith Games
# 8          9        (-)               리니지M           NCSOFT Corporation
# 9         10        (-)                 V4                NEXON Company
# 10        11        (-)              달빛조각사            Kakao Games Corp.
# 11        12       (+1)           검은사막 모바일                  PEARL ABYSS
# ...

# %%
import glob

path = "./game_crawling/*"
file_list = glob.glob(path)
file_list_py = [file for file in file_list if file.endswith(".py")]

print ("file_list_py: {}".format(file_list_py))
# Out:
# file_list_py: []

# %%
import os


mobile = [i for i in os.listdir('./game_crawling/') if 'mobile' in i]
pc = [i for i in os.listdir('./game_crawling/') if 'pc' in i]
steam = [i for i in os.listdir('./game_crawling/') if 'steam' in i]

# %%
steam
# Out:
# ['steam_202003_4.csv',
#  'steam_202003_5.csv',
#  'steam_202004_1.csv',
#  'steam_202004_2.csv',
#  'steam_202004_3.csv',
#  'steam_202004_4.csv',
#  'steam_202005_1.csv',
#  'steam_202005_2.csv',
#  'steam_202005_3.csv',
#  'steam_202005_4.csv',
#  'steam_202006_1.csv',
#  'steam_202006_2.csv',
#  'steam_202006_3.csv',
#  'steam_202006_4.csv',
#  'steam_202007_1.csv',
#  'steam_202007_2.csv',
#  'steam_202007_3.csv',
#  'steam_202007_4.csv',
#  'steam_202007_5.csv',
#  'steam_202008_1.csv',
#  'steam_202008_2.csv',
#  'steam_202008_3.csv',
#  'steam_202008_4.csv',
#  'steam_202009_1.csv',
#  'steam_202009_2.csv',
#  'steam_202009_3.csv',
#  'steam_202009_4.csv',
#  'steam_202009_5.csv',
#  'steam_202010_2.csv',
#  'steam_202010_3.csv',
#  'steam_202010_4.csv',
#  'steam_202010_5.csv',
#  'steam_202011_1.csv',
#  'steam_202011_2.csv',
#  'steam_202011_3.csv',
#  'steam_202011_4.csv',
#  'steam_202011_5.csv',
#  'steam_202012_2.csv',
#  'steam_202012_3.csv',
#  'steam_202012_4.csv',
# ...

# %%
steam[2]
# Out:
# 'steam_202004_1.csv'

# %%
file = steam[2]
df = pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
df
# Out:
#     column-1 column-1 2                                      column-2 href  \
# 0          1        (-)            https://trees.gamemeca.com/battleground
# 1          2      (NEW)                                                NaN
# 2          3       (-1)          https://trees.gamemeca.com/stardew_valley
# 3          4        (-)      https://trees.gamemeca.com/grand_theft_auto_v
# 4          5        (-)         https://trees.gamemeca.com/onpiecepiratew4
# 5          6      (+18)    https://trees.gamemeca.com/monster_hunter_world
# 6          7       (-1)             https://trees.gamemeca.com/doometernal
# 7          8       (-1)  https://trees.gamemeca.com/tom_clancys_rainbow...
# 8          9      (NEW)         https://trees.gamemeca.com/human_fall_flat
# 9         10        (-)                 https://trees.gamemeca.com/nba2k20
# 10        11       (-3)  https://trees.gamemeca.com/romance_of_the_thre...
# ...

# %%
file = steam[1]
df = pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
df
# Out:
#     column-1 column-1 2                                      column-2 href  \
# 0          1        (-)            https://trees.gamemeca.com/battleground
# 1          2        (-)          https://trees.gamemeca.com/stardew_valley
# 2          3      (NEW)                                                NaN
# 3          4       (-1)      https://trees.gamemeca.com/grand_theft_auto_v
# 4          5       (-1)                                                NaN
# 5          6       (-1)                                                NaN
# 6          7      (NEW)  https://trees.gamemeca.com/tom_clancys_rainbow...
# 7          8       (-1)  https://trees.gamemeca.com/romance_of_the_thre...
# 8          9       (-3)             https://trees.gamemeca.com/arksurvival
# 9          9      (NEW)                                                NaN
# 10        11       (-3)      https://trees.gamemeca.com/reddeadredemption2
# ...

# %%
mobile[74]
# Out:
# 'mobile_202003_3.csv'

# %%
file = mobile[76]
df1 = pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
df1
# Out:
#     column-1 column-1 2                                      column-2 href  \
# 0          1        (-)                      https://trees.gamemeca.com/a3
# 1          2      (+17)                  https://trees.gamemeca.com/league
# 2          3       (-1)             https://trees.gamemeca.com/lineage2m19
# 3          4       (+1)                https://trees.gamemeca.com/terahero
# 4          5       (-1)                  https://trees.gamemeca.com/roblox
# 5          6       (-3)                https://trees.gamemeca.com/hgame_gp
# 6          7       (-1)              https://trees.gamemeca.com/brawlstars
# 7          8       (+6)                   https://trees.gamemeca.com/aooni
# 8          9       (-1)              https://trees.gamemeca.com/lineagem19
# 9         10        (-)                    https://trees.gamemeca.com/v4kr
# 10        11        (-)               https://trees.gamemeca.com/moonlight
# ...

# %%
file = pc[77]
df1 = pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
df1
# Out:
#     column-1 column-1 2       column-2  \
# 0          1        (-)      리그 오브 레전드
# 1          2        (-)         메이플스토리
# 2          3        (-)         피파온라인4
# 3          4        (-)         배틀그라운드
# 4          5        (-)           서든어택
# 5          6        (-)         마인크래프트
# 6          7        (-)         던전앤파이터
# 7          8        (-)          카트라이더
# 8          9        (-)           오버워치
# 9         10        (-)          로스트아크
# 10        11        (-)          아키에이지
# 11        12        (-)       천하제일상 거상
# 12        13        (-)          테일즈런너
# 13        14        (-)           사이퍼즈
# 14        15       (+2)            리니지
# 15        16       (-1)      패스 오브 엑자일
# 16        17       (-1)           검은사막
# 17        18        (-)  크레이지 아케이드 비엔비
# 18        19        (-)        블레이드앤소울
# 19        20       (+1)     아이온: 영원의 탑
# 20        21       (-1)  스타크래프트: 브루드 워
# 21        22        (-)    월드 오브 워크래프트
# 22        23       (+1)          바람의나라
# ...

# %%
df_pic_all = pd.DataFrame()
for i in range(0, 2):
    file = steam[i] #슬레시 위치 정확하게 할 것!!
    df_pic= pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
    df_pic_all = pd.concat([df_pic_all, df_pic])

# %%
df_pic_all
# Out:
#     column-1                                      column-2 href  \
# 0          1            https://trees.gamemeca.com/battleground
# 1          2          https://trees.gamemeca.com/stardew_valley
# 2          3      https://trees.gamemeca.com/grand_theft_auto_v
# 3          4                                                NaN
# 4          5                                                NaN
# ..       ...                                                ...
# 35        36                                                NaN
# 36        37       https://trees.gamemeca.com/call_of_duty_wwii
# 37        38                                                NaN
# 38        39               https://trees.gamemeca.com/far_cry_5
# 39        40  https://trees.gamemeca.com/divinity_original_s...
#
#                                           rankimg src  \
# 0   https://trees.gamemeca.com/data/monthlyrank/st...
# 1   https://trees.gamemeca.com/data/monthlyrank/st...
# ...

# %%
df_nonpic_all = pd.DataFrame()
for i in range(3, 122):
    file = steam[i] #슬레시 위치 정확하게 할 것!!
    df_nonpic= pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
    df_nonpic_all = pd.concat([df_nonpic_all, df_nonpic])

# %%
df_nonpic_all = df_nonpic_all[['column-1', 'column-1 2', 'column-2', 'column-3', 'column-4']]

# %%
df_nonpic_all
# Out:
#     column-1 column-1 2                        column-2  \
# 0          1        (-)                 플레이어언노운스 배틀그라운드
# 1          2        (-)  히트맨 - GAME OF THE YEAR EDITION
# 2          3        (-)                           스타듀밸리
# 3          4        (-)                            GTA5
# 4          5        (-)                     원피스: 해적무쌍 4
# ..       ...        ...                             ...
# 35        36       (-1)                         그랜드 체이스
# 36        37       (-7)                              쿼리
# 37        38       (-1)                             문명6
# 38        39       (-3)                           삼국지14
# 39        40       (-1)                           V 라이징
#
#                       column-3   column-4
# 0             PUBG Corporation        FPS
# 1           Io-Interactive A/S         액션
# 2                 ConcernedApe       롤플레잉
# 3               Rockstar Games         액션
# 4   BANDAI NAMCO Entertainment         액션
# ...

# %%
df_pic_all = df_pic_all[['column-1', 'column-1 2', 'column-3', 'column-4', 'column-5']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\haknyan\Documents\debbu\gameData\test.ipynb 셀 26 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/haknyan/Documents/debbu/gameData/test.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> df_pic_all = df_pic_all[['column-1', 'column-1 2', 'column-3', 'column-4', 'column-5']]
#
# File c:\Users\haknyan\miniconda3\envs\dataLab\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\haknyan\miniconda3\envs\dataLab\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
# ...

# %%
df_pic_all
# Out:
#     column-1 column-1 2                       column-2  \
# 0          1        NaN  PLAYERUNKNOWN'S BATTLEGROUNDS
# 1          2        NaN                 Stardew Valley
# 2          3        NaN             Grand Theft Auto V
# 3          4        NaN   ONE PIECE: PIRATE WARRIORS 4
# 4          5        NaN                   DOOM Eternal
# ..       ...        ...                            ...
# 35        36      (-14)                    풋볼 매니저 2020
# 36        37       (-8)                  콜 오브 듀티: WWII
# 37        38      (-17)                           점프 킹
# 38        39       (-9)                         파크라이 5
# 39        40      (-19)                 디비니티: 오리지널 신 2
#
#                       column-3 column-4
# 0             PUBG Corporation      FPS
# 1                 ConcernedApe     롤플레잉
# 2               Rockstar Games       액션
# 3   BANDAI NAMCO Entertainment       액션
# 4           Bethesda Softworks       액션
# ..                         ...      ...
# ...

# %%
df_nonpic_all
# Out:
#     column-1 column-1 2                        column-2  \
# 0          1        (-)                 플레이어언노운스 배틀그라운드
# 1          2        (-)  히트맨 - GAME OF THE YEAR EDITION
# 2          3        (-)                           스타듀밸리
# 3          4        (-)                            GTA5
# 4          5        (-)                     원피스: 해적무쌍 4
# ..       ...        ...                             ...
# 35        36       (-1)                         그랜드 체이스
# 36        37       (-7)                              쿼리
# 37        38       (-1)                             문명6
# 38        39       (-3)                           삼국지14
# 39        40       (-1)                           V 라이징
#
#                       column-3   column-4
# 0             PUBG Corporation        FPS
# 1           Io-Interactive A/S         액션
# 2                 ConcernedApe       롤플레잉
# 3               Rockstar Games         액션
# 4   BANDAI NAMCO Entertainment         액션
# ...

# %%
df_pic_all.rename(columns = {'column-3' : 'column-2'}, inplace = True)
df_pic_all.rename(columns = {'column-4' : 'column-3'}, inplace = True)
df_pic_all.rename(columns = {'column-5' : 'column-4'}, inplace = True)
# Out:
# C:\Users\haknyan\AppData\Local\Temp\ipykernel_30332\453666154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pic_all.rename(columns = {'column-3' : 'column-2'}, inplace = True)
# C:\Users\haknyan\AppData\Local\Temp\ipykernel_30332\453666154.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pic_all.rename(columns = {'column-4' : 'column-3'}, inplace = True)
# C:\Users\haknyan\AppData\Local\Temp\ipykernel_30332\453666154.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_pic_all = df_pic_all.drop(columns=['column-2 href', 'rankimg src', 'column-3 href'])

# %%
df_pic_all
# Out:
#     column-1 column-1 2    column-3       column-4         column-5
# 0          1        (-)       로스트아크   스마일게이트 STOVE           MMORPG
# 1          2        (-)   리그 오브 레전드        라이엇 게임즈              AOS
# 2          3        (-)      피파온라인4  NEXON COMPANY              스포츠
# 3          4        (-)      메이플스토리         넥슨 코리아             롤플레잉
# 4          5        (-)       카트라이더  NEXON COMPANY           자동차 경주
# ..       ...        ...         ...            ...              ...
# 35        36        (-)        소울워커    ㈜스마일게이트메가포트           액션 RPG
# 36        37        (-)       버블파이터         ㈜넥슨코리아          캐주얼 TPS
# 37        38       (+1)       테일즈위버         ㈜넥슨코리아  드라마틱 온라인 액션 RPG
# 38        39       (+1)        클로저스         ㈜넥슨코리아        벨트 스크롤 액션
# 39        40      (NEW)  트리 오브 세이비어         ㈜넥슨코리아           MMORPG
#
# [2290 rows x 5 columns]

# %%
df_pic_all.rename(columns = {'column-3' : 'column-2'}, inplace = True)
df_pic_all.rename(columns = {'column-4' : 'column-3'}, inplace = True)
df_pic_all.rename(columns = {'column-5' : 'column-4'}, inplace = True)

# %%
df_pic_all
# Out:
#     column-1 column-1 2    column-2       column-3         column-4
# 0          1        (-)       로스트아크   스마일게이트 STOVE           MMORPG
# 1          2        (-)   리그 오브 레전드        라이엇 게임즈              AOS
# 2          3        (-)      피파온라인4  NEXON COMPANY              스포츠
# 3          4        (-)      메이플스토리         넥슨 코리아             롤플레잉
# 4          5        (-)       카트라이더  NEXON COMPANY           자동차 경주
# ..       ...        ...         ...            ...              ...
# 35        36        (-)        소울워커    ㈜스마일게이트메가포트           액션 RPG
# 36        37        (-)       버블파이터         ㈜넥슨코리아          캐주얼 TPS
# 37        38       (+1)       테일즈위버         ㈜넥슨코리아  드라마틱 온라인 액션 RPG
# 38        39       (+1)        클로저스         ㈜넥슨코리아        벨트 스크롤 액션
# 39        40      (NEW)  트리 오브 세이비어         ㈜넥슨코리아           MMORPG
#
# [2290 rows x 5 columns]

# %%
df_nonpic_all.drop('column-2 href', axis=1, inplace=True)
df_nonpic_all
# Out:
#     column-1 column-1 2      column-2         column-3         column-4
# 0          1        (-)     리그 오브 레전드          라이엇 게임즈             MOBA
# 1          2        (-)        메이플스토리           ㈜넥슨코리아           MMORPG
# 2          3        (-)        피파온라인4           ㈜넥슨코리아              스포츠
# 3          4        (-)        배틀그라운드   펍지주식회사, 카카오게임즈          서바이벌 슈팅
# 4          5        (-)          서든어택           ㈜넥슨코리아              FPS
# ..       ...        ...           ...              ...              ...
# 35        36       (+2)         테일즈위버           ㈜넥슨코리아  드라마틱 온라인 액션 RPG
# 36        37       (-1)  콜 오브 듀티: 뱅가드  블리자드 엔터테인먼트 코리아              FPS
# 37        38       (-1)         포트나이트            에픽게임즈     빌딩 서바이벌 배틀로얄
# 38        39        (-)            아바          (주)네오위즈          FPS/TPS
# 39        40      (NEW)          하스스톤      블리자드 엔터테인먼트              CCG
#
# [4760 rows x 5 columns]

# %%
df_all = pd.DataFrame()
df_all = pd.concat([df_pic_all, df_nonpic_all])

# %%
df_all
# Out:
#     column-1 column-1 2                       column-2  \
# 0          1        NaN  PLAYERUNKNOWN'S BATTLEGROUNDS
# 1          2        NaN                 Stardew Valley
# 2          3        NaN             Grand Theft Auto V
# 3          4        NaN   ONE PIECE: PIRATE WARRIORS 4
# 4          5        NaN                   DOOM Eternal
# ..       ...        ...                            ...
# 35        36       (-1)                        그랜드 체이스
# 36        37       (-7)                             쿼리
# 37        38       (-1)                            문명6
# 38        39       (-3)                          삼국지14
# 39        40       (-1)                          V 라이징
#
#                       column-3   column-4
# 0             PUBG Corporation        FPS
# 1                 ConcernedApe       롤플레잉
# 2               Rockstar Games         액션
# 3   BANDAI NAMCO Entertainment         액션
# 4           Bethesda Softworks         액션
# ..                         ...        ...
# ...

# %%
df_all.to_csv('steam_all.csv')
