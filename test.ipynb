# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.DataFrame(pd.read_csv('./game_crawling/pc_202004_2.csv'))

# %%
df1
# Out:
#     column-1 column-1 2       column-2  \
# 0          1        (-)      리그 오브 레전드
# 1          2        (-)         메이플스토리
# 2          3        (-)         피파온라인4
# 3          4        (-)         배틀그라운드
# 4          5        (-)           서든어택
# 5          6        (-)         마인크래프트
# 6          7        (-)         던전앤파이터
# 7          8        (-)          카트라이더
# 8          9        (-)           오버워치
# 9         10        (-)          로스트아크
# 10        11        (-)          아키에이지
# 11        12        (-)       천하제일상 거상
# 12        13        (-)          테일즈런너
# 13        14        (-)           사이퍼즈
# 14        15       (+2)            리니지
# 15        16       (-1)      패스 오브 엑자일
# 16        17       (-1)           검은사막
# 17        18        (-)  크레이지 아케이드 비엔비
# 18        19        (-)        블레이드앤소울
# 19        20       (+1)     아이온: 영원의 탑
# 20        21       (-1)  스타크래프트: 브루드 워
# 21        22        (-)    월드 오브 워크래프트
# 22        23       (+1)          바람의나라
# 23        24       (+1)           마비노기
# 24        25       (+1)     파이널 판타지 14
# 25        26       (+3)           하스스톤
# 26        27       (-4)          디아블로3
# 27        28       (-1)            엘소드
# 28        29       (-1)             테라
# 29        30        (-)       마비노기 영웅전
# 30        31        (-)           리니지2
# 31        32        (-)          포트나이트
# 32        33        (-)            라테일
# 33        34        (-)          스페셜포스
# 34        35        (-)          로스트사가
# 35        36       (+1)          버블파이터
# 36        37       (+3)     레전드 오브 룬테라
# 37        38       (-2)           소울워커
# 38        39       (-1)     트리 오브 세이비어
# 39        40       (-1)          테일즈위버
#
#                                     column-2 href         column-3  \
# 0      https://trees.gamemeca.com/leagueoflegends          라이엇 게임즈
# 1           https://trees.gamemeca.com/maplestory           ㈜넥슨코리아
# 2          https://trees.gamemeca.com/fifaonline4           ㈜넥슨코리아
# 3         https://trees.gamemeca.com/battleground   펍지주식회사, 카카오게임즈
# 4         https://trees.gamemeca.com/suddenattack           ㈜넥슨코리아
# 5            https://trees.gamemeca.com/minecraft     엑스박스 게임 스튜디오
# 6                   https://trees.gamemeca.com/df           ㈜넥슨코리아
# 7            https://trees.gamemeca.com/kartrider           ㈜넥슨코리아
# 8        https://trees.gamemeca.com/playoverwatch      블리자드 엔터테인먼트
# 9              https://trees.gamemeca.com/lostark       ㈜스마일게이트알피지
# 10          https://trees.gamemeca.com/archeageon          ㈜엑스엘게임즈
# 11             https://trees.gamemeca.com/gersang       ㈜에이케이인터렉티브
# 12         https://trees.gamemeca.com/talesrunner      ㈜스마일게이트메가포트
# 13             https://trees.gamemeca.com/cyphers           ㈜넥슨코리아
# 14           https://trees.gamemeca.com/lineageon           ㈜엔씨소프트
# 15                 https://trees.gamemeca.com/poe          ㈜카카오게임즈
# 16        https://trees.gamemeca.com/black_desert            ㈜펄어비스
# 17               https://trees.gamemeca.com/cabnb           ㈜넥슨코리아
# 18                 https://trees.gamemeca.com/bns           ㈜엔씨소프트
# 19                https://trees.gamemeca.com/aion           ㈜엔씨소프트
# 20        https://trees.gamemeca.com/starcraft_bw  블리자드 엔터테인먼트 코리아
# 21                 https://trees.gamemeca.com/wow  블리자드 엔터테인먼트 코리아
# 22               https://trees.gamemeca.com/baram           ㈜넥슨코리아
# 23            https://trees.gamemeca.com/mabinogi           ㈜넥슨코리아
# 24                https://trees.gamemeca.com/ff14          ㈜액토즈소프트
# 25         https://trees.gamemeca.com/hearthstone      블리자드 엔터테인먼트
# 26             https://trees.gamemeca.com/diablo3  블리자드 엔터테인먼트 코리아
# 27             https://trees.gamemeca.com/elsword           ㈜넥슨코리아
# 28              https://trees.gamemeca.com/teraon           ㈜넥슨코리아
# 29     https://trees.gamemeca.com/mabinogi_heroes           ㈜넥슨코리아
# 30         https://trees.gamemeca.com/lineageonii           ㈜엔씨소프트
# 31            https://trees.gamemeca.com/fortnite            에픽게임즈
# 32            https://trees.gamemeca.com/latalepc          ㈜액토즈소프트
# 33        https://trees.gamemeca.com/specialforce          ㈜드래곤플라이
# 34            https://trees.gamemeca.com/lostsaga            ㈜위메이드
# 35                  https://trees.gamemeca.com/bf           ㈜넥슨코리아
# 36  https://trees.gamemeca.com/legendsofruneterra          라이엇 게임즈
# 37          https://trees.gamemeca.com/soulworker      ㈜스마일게이트메가포트
# 38        https://trees.gamemeca.com/treeofsavior           ㈜넥슨코리아
# 39         https://trees.gamemeca.com/talesewaver           ㈜넥슨코리아
#
#            column-4
# 0              MOBA
# 1            MMORPG
# 2               스포츠
# 3           서바이벌 슈팅
# 4               FPS
# 5              샌드박스
# 6     벨트 스크롤 액션 RPG
# 7               레이싱
# 8           팀 기반 슈팅
# 9      핵앤슬래시 MMORPG
# 10          판타지 RPG
# 11           MMORPG
# 12              레이싱
# 13               액션
# 14           MMORPG
# 15             ARPG
# 16           MMORPG
# 17             아케이드
# 18           MMORPG
# 19           MMORPG
# 20              RTS
# 21           MMORPG
# 22           MMORPG
# 23           MMORPG
# 24           MMORPG
# 25              CCG
# 26             롤플레잉
# 27   횡스크롤 액션 MMORPG
# 28           MMORPG
# 29           액션 RPG
# 30           MMORPG
# 31     빌딩 서바이벌 배틀로얄
# 32   횡스크롤 액션 MMORPG
# 33              FPS
# 34               액션
# 35          캐주얼 TPS
# 36            카드 전략
# 37           액션 RPG
# 38           MMORPG
# 39  드라마틱 온라인 액션 RPG

# %%
df2 = pd.DataFrame(pd.read_csv('./game_crawling/mobile_202204_2.csv'))

# %%
df2
# Out:
#     column-1 column-1 2            column-2  \
# 0          1        (-)          던전앤파이터 모바일
# 1          2        (-)              ROBLOX
# 2          3        (-)                리니지M
# 3          4        (-)                리니지W
# 4          5        (-)         오딘: 발할라 라이징
# 5          6        (-)                언디셈버
# 6          7       (+1)             바람의나라 연
# 7          8       (-1)                  원신
# 8          9        (-)               리니지2M
# 9         10        (-)             쿠키런: 킹덤
# 10        11        (-)            전략적 팀 전투
# 11        12       (+3)       넷마블 프로야구 2022
# 12        13        (-)               브롤스타즈
# 13        14        (-)              제2의 나라
# 14        15       (+1)                포켓몬고
# 15        16       (-4)               뮤오리진3
# 16        17       (+2)              피파 모바일
# 17        18        (-)            히어로즈 테일즈
# 18        19       (-2)            검은사막 모바일
# 19        20      (NEW)          컴투스프로야구V22
# 20        21        (-)              냥코 대전쟁
# 21        22       (-2)             블루 아카이브
# 22        23       (+1)             메이플스토리M
# 23        24       (-1)              세븐나이츠2
# 24        25       (-3)         카트라이더 러쉬플러스
# 25        26       (-1)             삼국지 전략판
# 26        27       (-1)     더 킹 오브 파이터즈 올스타
# 27        28       (+6)          라이즈 오브 킹덤즈
# 28        29       (+2)                 미르4
# 29        30       (+2)                  V4
# 30        31       (-4)              좀비고등학교
# 31        32       (-4)            블레이드&소울2
# 32        33        (-)    일곱개의 대죄: 그랜드 크로스
# 33        34       (+3)             팔라독 택틱스
# 34        35        (-)  리그 오브 레전드: 와일드 리프트
# 35        36       (-6)            트라하 인피니티
# 36        37       (-8)          A3: 스틸얼라이브
# 37        38       (-2)              카운터사이드
# 38        39       (+1)                그랑사가
# 39        40      (NEW)            블레이드 키우기
#
#                                   column-2 href                 column-3  \
# 0               https://trees.gamemeca.com/mdnf            NEXON Company
# 1             https://trees.gamemeca.com/roblox       Roblox Corporation
# 2         https://trees.gamemeca.com/lineagem19       NCSOFT Corporation
# 3           https://trees.gamemeca.com/lineagew                   NCSOFT
# 4               https://trees.gamemeca.com/odin        KAKAO GAMES CORP.
# 5         https://trees.gamemeca.com/undecember               LINE Games
# 6            https://trees.gamemeca.com/baram_m            NEXON Company
# 7            https://trees.gamemeca.com/genshin           miHoYo Limited
# 8        https://trees.gamemeca.com/lineage2m19       NCSOFT Corporation
# 9   https://trees.gamemeca.com/cookierunkingdom   Devsisters Corporation
# 10            https://trees.gamemeca.com/league          Riot Games, Inc
# 11           https://trees.gamemeca.com/ma9rekr                Netmarble
# 12        https://trees.gamemeca.com/brawlstars                Supercell
# 13           https://trees.gamemeca.com/2worlds                Netmarble
# 14         https://trees.gamemeca.com/pokemongo            Niantic, Inc.
# 15         https://trees.gamemeca.com/muorigin3              Webzen Inc.
# 16               https://trees.gamemeca.com/fmk            NEXON Company
# 17       https://trees.gamemeca.com/heroestales          37 MOBILE GAMES
# 18      https://trees.gamemeca.com/blackdesertm              PEARL ABYSS
# 19              https://trees.gamemeca.com/cpbv                   Com2uS
# 20      https://trees.gamemeca.com/battlecatskr        PONOS Corporation
# 21       https://trees.gamemeca.com/bluearchive            NEXON Company
# 22            https://trees.gamemeca.com/maplem            NEXON Company
# 23     https://trees.gamemeca.com/sevenknights2                Netmarble
# 24         https://trees.gamemeca.com/nexonkart            NEXON Company
# 25            https://trees.gamemeca.com/sgzzlb             Qookka Games
# 26        https://trees.gamemeca.com/kofallstar                Netmarble
# 27               https://trees.gamemeca.com/rok             Lilith Games
# 28              https://trees.gamemeca.com/mir4          Wemade Co., Ltd
# 29              https://trees.gamemeca.com/v4kr            NEXON Company
# 30             https://trees.gamemeca.com/aooni             AWESOMEPIECE
# 31            https://trees.gamemeca.com/bns219                   NCSOFT
# 32       https://trees.gamemeca.com/sevenguilty                Netmarble
# 33    https://trees.gamemeca.com/paladogtactics        GRAVITY Co., Ltd.
# 34          https://trees.gamemeca.com/wildrift          Riot Games, Inc
# 35     https://trees.gamemeca.com/trahainfinity  MOAI GAMES Corporation.
# 36                https://trees.gamemeca.com/a3                Netmarble
# 37       https://trees.gamemeca.com/counterside            NEXON Company
# 38          https://trees.gamemeca.com/gransaga                   NPIXEL
# 39                                          NaN                  mobirix
#
#    column-4
# 0      롤플레잉
# 1      어드벤처
# 2      롤플레잉
# 3      롤플레잉
# 4      롤플레잉
# 5      롤플레잉
# 6      롤플레잉
# 7      어드벤처
# 8      롤플레잉
# 9      롤플레잉
# 10       전략
# 11      스포츠
# 12       액션
# 13     롤플레잉
# 14     어드벤처
# 15     롤플레잉
# 16      스포츠
# 17     롤플레잉
# 18     롤플레잉
# 19      스포츠
# 20   캐주얼 게임
# 21     롤플레잉
# 22     롤플레잉
# 23     롤플레잉
# 24   자동차 경주
# 25       전략
# 26     롤플레잉
# 27       전략
# 28     롤플레잉
# 29     롤플레잉
# 30     아케이드
# 31     롤플레잉
# 32     롤플레잉
# 33   캐주얼 게임
# 34       전략
# 35     롤플레잉
# 36     롤플레잉
# 37     롤플레잉
# 38     롤플레잉
# 39    시뮬레이션

# %%
df2 = pd.DataFrame(pd.read_csv('./game_crawling/pc_201901_2.csv'))

# %%
df2
# Out:
#     column-1 column-1 2                                    column-2 href  \
# 0          1        (-)               https://trees.gamemeca.com/lostark
# 1          2        (-)       https://trees.gamemeca.com/leagueoflegends
# 2          3       (+1)            https://trees.gamemeca.com/maplestory
# 3          4       (-1)           https://trees.gamemeca.com/fifaonline4
# 4          5        (-)             https://trees.gamemeca.com/kartrider
# 5          6        (-)          https://trees.gamemeca.com/battleground
# 6          7        (-)                    https://trees.gamemeca.com/df
# 7          8       (+1)          https://trees.gamemeca.com/suddenattack
# 8          9       (+1)         https://trees.gamemeca.com/playoverwatch
# 9         10       (+1)               https://trees.gamemeca.com/gersang
# 10        11       (+1)             https://trees.gamemeca.com/lineageon
# 11        12       (+2)             https://trees.gamemeca.com/minecraft
# 12        13       (-5)              https://trees.gamemeca.com/astellia
# 13        14       (+1)           https://trees.gamemeca.com/talesrunner
# 14        15       (+6)                   https://trees.gamemeca.com/bns
# 15        16       (-3)              https://trees.gamemeca.com/fortnite
# 16        17       (-1)               https://trees.gamemeca.com/cyphers
# 17        18       (+2)                 https://trees.gamemeca.com/cabnb
# 18        19       (-2)                  https://trees.gamemeca.com/aion
# 19        20       (-2)          https://trees.gamemeca.com/black_desert
# 20        21       (-2)               https://trees.gamemeca.com/elsword
# 21        22        (-)                 https://trees.gamemeca.com/baram
# 22        23        (-)           https://trees.gamemeca.com/lineageonii
# 23        24        (-)            https://trees.gamemeca.com/battlerite
# 24        25       (+1)              https://trees.gamemeca.com/mabinogi
# 25        26       (-1)       https://trees.gamemeca.com/mabinogi_heroes
# 26        27      (new)              https://trees.gamemeca.com/latalepc
# 27        28       (+1)               https://trees.gamemeca.com/closers
# 28        29       (+1)                    https://trees.gamemeca.com/bf
# 29        30       (+2)          https://trees.gamemeca.com/starcraft_bw
# 30        31        (-)  https://trees.gamemeca.com/monster_hunter_world
# 31        32       (-4)               https://trees.gamemeca.com/wow-tip
#
#                                           rankimg src       column-3  \
# 0   https://trees.gamemeca.com/data/monthlyrank/pc...          로스트아크
# 1   https://trees.gamemeca.com/data/monthlyrank/pc...      리그 오브 레전드
# 2   https://trees.gamemeca.com/data/monthlyrank/pc...         메이플스토리
# 3   https://trees.gamemeca.com/data/monthlyrank/pc...         피파온라인4
# 4   https://trees.gamemeca.com/data/monthlyrank/pc...          카트라이더
# 5   https://trees.gamemeca.com/data/monthlyrank/pc...         배틀그라운드
# 6   https://trees.gamemeca.com/data/monthlyrank/pc...         던전앤파이터
# 7   https://trees.gamemeca.com/data/monthlyrank/pc...           서든어택
# 8   https://trees.gamemeca.com/data/monthlyrank/pc...           오버워치
# 9   https://trees.gamemeca.com/data/monthlyrank/pc...       천하제일상 거상
# 10  https://trees.gamemeca.com/data/monthlyrank/pc...            리니지
# 11  https://trees.gamemeca.com/data/monthlyrank/pc...         마인크래프트
# 12  https://trees.gamemeca.com/data/monthlyrank/pc...          아스텔리아
# 13  https://trees.gamemeca.com/data/monthlyrank/pc...          테일즈런너
# 14  https://trees.gamemeca.com/data/monthlyrank/pc...        블레이드앤소울
# 15  https://trees.gamemeca.com/data/monthlyrank/pc...          포트나이트
# 16  https://trees.gamemeca.com/data/monthlyrank/pc...           사이퍼즈
# 17  https://trees.gamemeca.com/data/monthlyrank/pc...  크레이지 아케이드 비엔비
# 18  https://trees.gamemeca.com/data/monthlyrank/pc...     아이온: 영원의 탑
# 19  https://trees.gamemeca.com/data/monthlyrank/pc...           검은사막
# 20  https://trees.gamemeca.com/data/monthlyrank/pc...            엘소드
# 21  https://trees.gamemeca.com/data/monthlyrank/pc...          바람의나라
# 22  https://trees.gamemeca.com/data/monthlyrank/pc...           리니지2
# 23  https://trees.gamemeca.com/data/monthlyrank/pc...          배틀라이트
# 24  https://trees.gamemeca.com/data/monthlyrank/pc...           마비노기
# 25  https://trees.gamemeca.com/data/monthlyrank/pc...       마비노기 영웅전
# 26  https://trees.gamemeca.com/data/monthlyrank/pc...            라테일
# 27  https://trees.gamemeca.com/data/monthlyrank/pc...           클로저스
# 28  https://trees.gamemeca.com/data/monthlyrank/pc...          버블파이터
# 29  https://trees.gamemeca.com/data/monthlyrank/pc...  스타크래프트: 브루드 워
# 30  https://trees.gamemeca.com/data/monthlyrank/pc...       몬스터헌터 월드
# 31  https://trees.gamemeca.com/data/monthlyrank/pc...    월드 오브 워크래프트
#
#                    column-4 column-5
# 0              스마일게이트 STOVE   MMORPG
# 1                   라이엇 게임즈      AOS
# 2                    넥슨 코리아     롤플레잉
# 3             NEXON COMPANY      스포츠
# 4             NEXON COMPANY   자동차 경주
# 5   KAKAO GAMES CORP., PUBG      FPS
# 6                    넥슨 코리아       액션
# 7                    넥슨 코리아      FPS
# 8                      블리자드      FPS
# 9            AK INTERACTIVE     롤플레잉
# 10                    엔씨소프트     롤플레잉
# 11                       모장     어드벤처
# 12            NEXON COMPANY   MMORPG
# 13              스마일게이트 메가포트   캐주얼 게임
# 14                    엔씨소프트     롤플레잉
# 15                     네오위즈      RTS
# 16                   넥슨 코리아       액션
# 17                   넥슨 코리아   캐주얼 게임
# 18                    엔씨소프트     롤플레잉
# 19                   카카오게임즈     롤플레잉
# 20                   넥슨 코리아     롤플레잉
# 21                   넥슨 코리아     롤플레잉
# 22                    엔씨소프트     롤플레잉
# 23                    넥슨코리아      AOS
# 24                   넥슨 코리아     롤플레잉
# 25                   넥슨 코리아     롤플레잉
# 26                   액토즈소프트     롤플레잉
# 27                   넥슨 코리아       액션
# 28                로두마니 스튜디오   캐주얼 게임
# 29              블리자드 엔터테인먼트      RTS
# 30         CAPCOM CO., LTD.       액션
# 31                     블리자드     롤플레잉

# %%
df1.drop(['column-2 href'], axis=1, inplace=True)

# %%
df.drop(['column-2 href', 'rankimg src'], axis=1, inplace=True)

# %%
df
# Out:
#     column-1 column-1 2           column-3                     column-4  \
# 0          1        (-)         A3: 스틸얼라이브                    Netmarble
# 1          2        (-)           전략적 팀 전투              Riot Games, Inc
# 2          3        (-)              리니지2M           NCSOFT Corporation
# 3          4       (+1)             ROBLOX           Roblox Corporation
# 4          5      (NEW)            블레스 모바일                JOYCITY Corp.
# 5          6       (+2)             좀비고등학교                 AWESOMEPIECE
# 6          7        (-)              브롤스타즈                    Supercell
# 7          8       (-2)            AFK 아레나                 Lilith Games
# 8          9        (-)               리니지M           NCSOFT Corporation
# 9         10        (-)                 V4                NEXON Company
# 10        11        (-)              달빛조각사            Kakao Games Corp.
# 11        12       (+1)           검은사막 모바일                  PEARL ABYSS
# 12        13       (+1)             카운터사이드                NEXON Company
# 13        14       (+4)    더 킹 오브 파이터즈 올스타                    Netmarble
# 14        15        (-)            메이플스토리M                NEXON Company
# 15        16        (-)         라이즈 오브 킹덤즈                 Lilith Games
# 16        17       (+7)         로드 오브 히어로즈         Clover Games Co.,Ltd
# 17        18       (-1)         배틀그라운드 모바일             PUBG CORPORATION
# 18        19        (-)   일곱개의 대죄: 그랜드 크로스                    Netmarble
# 19        20      (-16)             테라 히어로       Red Sahara Studio Inc.
# 20        21       (-9)             카오스모바일                    (주)엑스엔게임즈
# 21        22       (-1)               포켓몬고                Niantic, Inc.
# 22        23       (-1)          리니지2 레볼루션                    Netmarble
# 23        24       (-1)               명일방주              Yostar Limited.
# 24        25      (NEW)          라그나로크 택틱스            GRAVITY Co., Ltd.
# 25        26        (-)    세븐나이츠 for kakao                    Netmarble
# 26        27       (-2)             랜덤 다이스                    royaldice
# 27        28       (-1)       블레이드&소울 레볼루션                    Netmarble
# 28        29        (-)             라스트오리진                    smart joy
# 29        30       (-2)               제5인격                  X.D. Global
# 30        31      (-11)                 R5  YOOZOO GAMES KOREA CO.,LTD.
# 31        32       (-2)    모두의마블 for kakao                    Netmarble
# 32        33       (-1)              이사만루3              GONGGAMES Corp.
# 33        34       (-1)          클래시 오브 클랜                    Supercell
# 34        35       (-4)             클래시 로얄                    Supercell
# 35        36       (+1)  프린세스 커넥트! Re:Dive            Kakao Games Corp.
# 36        37       (-1)               리치리치                   U.LU Games
# 37        38      (NEW)             에오스 레드             BluePotion Games
# 38        39       (-4)               랑그릿사                   ZlongGames
# 39        40       (-6)           엑소스 히어로즈                   LINE Games
#
#    column-5
# 0      롤플레잉
# 1        전략
# 2      롤플레잉
# 3      어드벤처
# 4      롤플레잉
# 5      아케이드
# 6        액션
# 7      롤플레잉
# 8      롤플레잉
# 9      롤플레잉
# 10     롤플레잉
# 11     롤플레잉
# 12     롤플레잉
# 13     롤플레잉
# 14     롤플레잉
# 15       전략
# 16     롤플레잉
# 17       액션
# 18     롤플레잉
# 19     롤플레잉
# 20     롤플레잉
# 21     어드벤처
# 22     롤플레잉
# 23       전략
# 24       전략
# 25     롤플레잉
# 26       전략
# 27     롤플레잉
# 28     롤플레잉
# 29     어드벤처
# 30     롤플레잉
# 31       보드
# 32      스포츠
# 33       전략
# 34       전략
# 35     롤플레잉
# 36    시뮬레이션
# 37     롤플레잉
# 38       전략
# 39     롤플레잉

# %%
import glob

path = "./game_crawling/*"
file_list = glob.glob(path)
file_list_py = [file for file in file_list if file.endswith(".py")]

print ("file_list_py: {}".format(file_list_py))
# Out:
# file_list_py: []

# %%
import os


mobile = [i for i in os.listdir('./game_crawling/') if 'mobile' in i]
pc = [i for i in os.listdir('./game_crawling/') if 'pc' in i]
steam = [i for i in os.listdir('./game_crawling/') if 'steam' in i]

# %%
pc
# Out:
# ['pc_201802.csv',
#  'pc_201803.csv',
#  'pc_201804.csv',
#  'pc_201805.csv',
#  'pc_201806.csv',
#  'pc_201807.csv',
#  'pc_201808.csv',
#  'pc_201809.csv',
#  'pc_201810.csv',
#  'pc_201811.csv',
#  'pc_201812.csv',
#  'pc_201901_1.csv',
#  'pc_201901_2.csv',
#  'pc_201901_3.csv',
#  'pc_201901_4.csv',
#  'pc_201902_1.csv',
#  'pc_201902_2.csv',
#  'pc_201902_3.csv',
#  'pc_201902_4.csv',
#  'pc_201903_1.csv',
#  'pc_201903_2.csv',
#  'pc_201903_3.csv',
#  'pc_201903_4.csv',
#  'pc_201904_1.csv',
#  'pc_201904_2.csv',
#  'pc_201904_3.csv',
#  'pc_201904_4.csv',
#  'pc_201904_5.csv',
#  'pc_201905_1.csv',
#  'pc_201905_2.csv',
#  'pc_201905_3.csv',
#  'pc_201905_4.csv',
#  'pc_201906_1.csv',
#  'pc_201906_2.csv',
#  'pc_201906_3.csv',
#  'pc_201906_4.csv',
#  'pc_201907_1.csv',
#  'pc_201907_2.csv',
#  'pc_201907_3.csv',
#  'pc_201907_4.csv',
#  'pc_201907_5.csv',
#  'pc_201908_1.csv',
#  'pc_201908_2.csv',
#  'pc_201908_3.csv',
#  'pc_201908_4.csv',
#  'pc_201909_1.csv',
#  'pc_201909_2.csv',
#  'pc_201909_3.csv',
#  'pc_201909_4.csv',
#  'pc_201909_5.csv',
#  'pc_201910_1.csv',
#  'pc_201910_2.csv',
#  'pc_201910_3.csv',
#  'pc_201910_4.csv',
#  'pc_201911_1.csv',
#  'pc_201911_2.csv',
#  'pc_201911_3.csv',
#  'pc_201911_4.csv',
#  'pc_201912_1.csv',
#  'pc_201912_2.csv',
#  'pc_201912_3.csv',
#  'pc_201912_4.csv',
#  'pc_201912_5.csv',
#  'pc_202001_1.csv',
#  'pc_202001_2.csv',
#  'pc_202001_3.csv',
#  'pc_202001_4.csv',
#  'pc_202002_1.csv',
#  'pc_202002_2.csv',
#  'pc_202002_3.csv',
#  'pc_202002_4.csv',
#  'pc_202003_1.csv',
#  'pc_202003_2.csv',
#  'pc_202003_3.csv',
#  'pc_202003_4.csv',
#  'pc_202003_5.csv',
#  'pc_202004_1.csv',
#  'pc_202004_2.csv',
#  'pc_202004_3.csv',
#  'pc_202004_4.csv',
#  'pc_202005_1.csv',
#  'pc_202005_2.csv',
#  'pc_202005_3.csv',
#  'pc_202005_4.csv',
#  'pc_202006_1.csv',
#  'pc_202006_2.csv',
#  'pc_202006_3.csv',
#  'pc_202006_4.csv',
#  'pc_202007_1.csv',
#  'pc_202007_2.csv',
#  'pc_202007_3.csv',
#  'pc_202007_4.csv',
#  'pc_202007_5.csv',
#  'pc_202008_1.csv',
#  'pc_202008_2.csv',
#  'pc_202008_3.csv',
#  'pc_202008_4.csv',
#  'pc_202009_1.csv',
#  'pc_202009_2.csv',
#  'pc_202009_3.csv',
#  'pc_202009_4.csv',
#  'pc_202009_5.csv',
#  'pc_202010_2.csv',
#  'pc_202010_3.csv',
#  'pc_202010_4.csv',
#  'pc_202010_5.csv',
#  'pc_202011_1.csv',
#  'pc_202011_2.csv',
#  'pc_202011_3.csv',
#  'pc_202011_4.csv',
#  'pc_202011_5.csv',
#  'pc_202012_2.csv',
#  'pc_202012_3.csv',
#  'pc_202012_4.csv',
#  'pc_202012_5.csv',
#  'pc_202101_1.csv',
#  'pc_202101_2.csv',
#  'pc_202101_3.csv',
#  'pc_202101_4.csv',
#  'pc_202102_1.csv',
#  'pc_202102_2.csv',
#  'pc_202102_3.csv',
#  'pc_202102_4.csv',
#  'pc_202103_1.csv',
#  'pc_202103_2.csv',
#  'pc_202103_3.csv',
#  'pc_202103_4.csv',
#  'pc_202104_1.csv',
#  'pc_202104_2.csv',
#  'pc_202104_3.csv',
#  'pc_202104_4.csv',
#  'pc_202104_5.csv',
#  'pc_202105_1.csv',
#  'pc_202105_2.csv',
#  'pc_202105_3.csv',
#  'pc_202105_4.csv',
#  'pc_202105_5.csv',
#  'pc_202106_2.csv',
#  'pc_202106_3.csv',
#  'pc_202106_4.csv',
#  'pc_202106_5.csv',
#  'pc_202107_2.csv',
#  'pc_202107_3.csv',
#  'pc_202107_4.csv',
#  'pc_202107_5.csv',
#  'pc_202108_1.csv',
#  'pc_202108_2.csv',
#  'pc_202108_3.csv',
#  'pc_202108_4.csv',
#  'pc_202108_5.csv',
#  'pc_202109_2.csv',
#  'pc_202109_3.csv',
#  'pc_202109_4.csv',
#  'pc_202109_5.csv',
#  'pc_202110_1.csv',
#  'pc_202110_2.csv',
#  'pc_202110_3.csv',
#  'pc_202110_4.csv',
#  'pc_202111_1.csv',
#  'pc_202111_2.csv',
#  'pc_202111_3.csv',
#  'pc_202111_4.csv',
#  'pc_202111_5.csv',
#  'pc_202112_2.csv',
#  'pc_202112_3.csv',
#  'pc_202112_4.csv',
#  'pc_202112_5.csv',
#  'pc_202201_1.csv',
#  'pc_202201_2.csv',
#  'pc_202201_3.csv',
#  'pc_202201_4.csv',
#  'pc_202201_5.csv',
#  'pc_202202_2.csv',
#  'pc_202202_3.csv',
#  'pc_202202_4.csv',
#  'pc_202202_5.csv',
#  'pc_202203_2.csv',
#  'pc_202203_3.csv',
#  'pc_202203_4.csv',
#  'pc_202203_5.csv',
#  'pc_202204_1.csv',
#  'pc_202204_2.csv',
#  'pc_202204_3.csv',
#  'pc_202204_4.csv',
#  'pc_202205_1.csv',
#  'pc_202205_2.csv',
#  'pc_202205_3.csv',
#  'pc_202205_4.csv',
#  'pc_202205_5.csv',
#  'pc_202206_2.csv',
#  'pc_202206_3.csv',
#  'pc_202206_4.csv',
#  'pc_202206_5.csv',
#  'pc_202207_1.csv',
#  'pc_202207_2.csv',
#  'pc_202207_3.csv',
#  'pc_202207_4.csv']

# %%
pc[11]
# Out:
# 'pc_201901_1.csv'

# %%
pc[196]
# Out:
# 'pc_202207_4.csv'

# %%
mobile[196]
# Out:
# 'mobile_202207_4.csv'

# %%
file = pc[77]

df = pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
df
# Out:
#     column-1 column-1 2       column-2  \
# 0          1        (-)      리그 오브 레전드
# 1          2        (-)         메이플스토리
# 2          3        (-)         피파온라인4
# 3          4        (-)         배틀그라운드
# 4          5        (-)           서든어택
# 5          6        (-)         마인크래프트
# 6          7        (-)         던전앤파이터
# 7          8        (-)          카트라이더
# 8          9        (-)           오버워치
# 9         10        (-)          로스트아크
# 10        11        (-)          아키에이지
# 11        12        (-)       천하제일상 거상
# 12        13        (-)          테일즈런너
# 13        14        (-)           사이퍼즈
# 14        15       (+2)            리니지
# 15        16       (-1)      패스 오브 엑자일
# 16        17       (-1)           검은사막
# 17        18        (-)  크레이지 아케이드 비엔비
# 18        19        (-)        블레이드앤소울
# 19        20       (+1)     아이온: 영원의 탑
# 20        21       (-1)  스타크래프트: 브루드 워
# 21        22        (-)    월드 오브 워크래프트
# 22        23       (+1)          바람의나라
# 23        24       (+1)           마비노기
# 24        25       (+1)     파이널 판타지 14
# 25        26       (+3)           하스스톤
# 26        27       (-4)          디아블로3
# 27        28       (-1)            엘소드
# 28        29       (-1)             테라
# 29        30        (-)       마비노기 영웅전
# 30        31        (-)           리니지2
# 31        32        (-)          포트나이트
# 32        33        (-)            라테일
# 33        34        (-)          스페셜포스
# 34        35        (-)          로스트사가
# 35        36       (+1)          버블파이터
# 36        37       (+3)     레전드 오브 룬테라
# 37        38       (-2)           소울워커
# 38        39       (-1)     트리 오브 세이비어
# 39        40       (-1)          테일즈위버
#
#                                     column-2 href         column-3  \
# 0      https://trees.gamemeca.com/leagueoflegends          라이엇 게임즈
# 1           https://trees.gamemeca.com/maplestory           ㈜넥슨코리아
# 2          https://trees.gamemeca.com/fifaonline4           ㈜넥슨코리아
# 3         https://trees.gamemeca.com/battleground   펍지주식회사, 카카오게임즈
# 4         https://trees.gamemeca.com/suddenattack           ㈜넥슨코리아
# 5            https://trees.gamemeca.com/minecraft     엑스박스 게임 스튜디오
# 6                   https://trees.gamemeca.com/df           ㈜넥슨코리아
# 7            https://trees.gamemeca.com/kartrider           ㈜넥슨코리아
# 8        https://trees.gamemeca.com/playoverwatch      블리자드 엔터테인먼트
# 9              https://trees.gamemeca.com/lostark       ㈜스마일게이트알피지
# 10          https://trees.gamemeca.com/archeageon          ㈜엑스엘게임즈
# 11             https://trees.gamemeca.com/gersang       ㈜에이케이인터렉티브
# 12         https://trees.gamemeca.com/talesrunner      ㈜스마일게이트메가포트
# 13             https://trees.gamemeca.com/cyphers           ㈜넥슨코리아
# 14           https://trees.gamemeca.com/lineageon           ㈜엔씨소프트
# 15                 https://trees.gamemeca.com/poe          ㈜카카오게임즈
# 16        https://trees.gamemeca.com/black_desert            ㈜펄어비스
# 17               https://trees.gamemeca.com/cabnb           ㈜넥슨코리아
# 18                 https://trees.gamemeca.com/bns           ㈜엔씨소프트
# 19                https://trees.gamemeca.com/aion           ㈜엔씨소프트
# 20        https://trees.gamemeca.com/starcraft_bw  블리자드 엔터테인먼트 코리아
# 21                 https://trees.gamemeca.com/wow  블리자드 엔터테인먼트 코리아
# 22               https://trees.gamemeca.com/baram           ㈜넥슨코리아
# 23            https://trees.gamemeca.com/mabinogi           ㈜넥슨코리아
# 24                https://trees.gamemeca.com/ff14          ㈜액토즈소프트
# 25         https://trees.gamemeca.com/hearthstone      블리자드 엔터테인먼트
# 26             https://trees.gamemeca.com/diablo3  블리자드 엔터테인먼트 코리아
# 27             https://trees.gamemeca.com/elsword           ㈜넥슨코리아
# 28              https://trees.gamemeca.com/teraon           ㈜넥슨코리아
# 29     https://trees.gamemeca.com/mabinogi_heroes           ㈜넥슨코리아
# 30         https://trees.gamemeca.com/lineageonii           ㈜엔씨소프트
# 31            https://trees.gamemeca.com/fortnite            에픽게임즈
# 32            https://trees.gamemeca.com/latalepc          ㈜액토즈소프트
# 33        https://trees.gamemeca.com/specialforce          ㈜드래곤플라이
# 34            https://trees.gamemeca.com/lostsaga            ㈜위메이드
# 35                  https://trees.gamemeca.com/bf           ㈜넥슨코리아
# 36  https://trees.gamemeca.com/legendsofruneterra          라이엇 게임즈
# 37          https://trees.gamemeca.com/soulworker      ㈜스마일게이트메가포트
# 38        https://trees.gamemeca.com/treeofsavior           ㈜넥슨코리아
# 39         https://trees.gamemeca.com/talesewaver           ㈜넥슨코리아
#
#            column-4
# 0              MOBA
# 1            MMORPG
# 2               스포츠
# 3           서바이벌 슈팅
# 4               FPS
# 5              샌드박스
# 6     벨트 스크롤 액션 RPG
# 7               레이싱
# 8           팀 기반 슈팅
# 9      핵앤슬래시 MMORPG
# 10          판타지 RPG
# 11           MMORPG
# 12              레이싱
# 13               액션
# 14           MMORPG
# 15             ARPG
# 16           MMORPG
# 17             아케이드
# 18           MMORPG
# 19           MMORPG
# 20              RTS
# 21           MMORPG
# 22           MMORPG
# 23           MMORPG
# 24           MMORPG
# 25              CCG
# 26             롤플레잉
# 27   횡스크롤 액션 MMORPG
# 28           MMORPG
# 29           액션 RPG
# 30           MMORPG
# 31     빌딩 서바이벌 배틀로얄
# 32   횡스크롤 액션 MMORPG
# 33              FPS
# 34               액션
# 35          캐주얼 TPS
# 36            카드 전략
# 37           액션 RPG
# 38           MMORPG
# 39  드라마틱 온라인 액션 RPG

# %%
file = steam[0]
df = pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
df
# Out:
#     column-1                                      column-2 href  \
# 0          1            https://trees.gamemeca.com/battleground
# 1          2          https://trees.gamemeca.com/stardew_valley
# 2          3      https://trees.gamemeca.com/grand_theft_auto_v
# 3          4                                                NaN
# 4          5                                                NaN
# 5          6    https://trees.gamemeca.com/ark_survival_evolved
# 6          7  https://trees.gamemeca.com/romance_of_the_thre...
# 7          8      https://trees.gamemeca.com/reddeadredemption2
# 8          9  https://trees.gamemeca.com/ori_and_the_blind_f...
# 9         10                                                NaN
# 10        11              https://trees.gamemeca.com/the_forest
# 11        12           https://trees.gamemeca.com/house_flipper
# 12        13                    https://trees.gamemeca.com/Raft
# 13        14  https://trees.gamemeca.com/The_Witcher_3_Wild_...
# 14        15    https://trees.gamemeca.com/monster_hunter_world
# 15        16                https://trees.gamemeca.com/Terraria
# 16        17                                                NaN
# 17        18            https://trees.gamemeca.com/dark_souls_3
# 18        19        https://trees.gamemeca.com/Dead_by_Daylight
# 19        20                                                NaN
# 20        21                                                NaN
# 21        22                                                NaN
# 22        23                                                NaN
# 23        24                                                NaN
# 24        25  https://trees.gamemeca.com/Viscera_Cleanup_Detail
# 25        26    https://trees.gamemeca.com/Dont_Starve_Together
# 26        27                                                NaN
# 27        28        https://trees.gamemeca.com/Wallpaper_Engine
# 28        29                                                NaN
# 29        30               https://trees.gamemeca.com/Far_Cry_5
# 30        31                                                NaN
# 31        32           https://trees.gamemeca.com/7_Days_to_Die
# 32        33                                                NaN
# 33        34                                                NaN
# 34        35                                                NaN
# 35        36                                                NaN
# 36        37                                                NaN
# 37        38                                                NaN
# 38        39                                                NaN
# 39        40                                                NaN
#
#                                           rankimg src  \
# 0   https://trees.gamemeca.com/data/monthlyrank/st...
# 1   https://trees.gamemeca.com/data/monthlyrank/st...
# 2   https://trees.gamemeca.com/data/monthlyrank/st...
# 3   https://trees.gamemeca.com/data/monthlyrank/st...
# 4   https://trees.gamemeca.com/data/monthlyrank/st...
# 5   https://trees.gamemeca.com/data/monthlyrank/st...
# 6   https://trees.gamemeca.com/data/monthlyrank/st...
# 7   https://trees.gamemeca.com/data/monthlyrank/st...
# 8   https://trees.gamemeca.com/data/monthlyrank/st...
# 9   https://trees.gamemeca.com/data/monthlyrank/st...
# 10  https://trees.gamemeca.com/data/monthlyrank/st...
# 11  https://trees.gamemeca.com/data/monthlyrank/st...
# 12  https://trees.gamemeca.com/data/monthlyrank/st...
# 13  https://trees.gamemeca.com/data/monthlyrank/st...
# 14  https://trees.gamemeca.com/data/monthlyrank/st...
# 15  https://trees.gamemeca.com/data/monthlyrank/st...
# 16  https://trees.gamemeca.com/data/monthlyrank/st...
# 17  https://trees.gamemeca.com/data/monthlyrank/st...
# 18  https://trees.gamemeca.com/data/monthlyrank/st...
# 19  https://trees.gamemeca.com/data/monthlyrank/st...
# 20  https://trees.gamemeca.com/data/monthlyrank/st...
# 21  https://trees.gamemeca.com/data/monthlyrank/st...
# 22  https://trees.gamemeca.com/data/monthlyrank/st...
# 23  https://trees.gamemeca.com/data/monthlyrank/st...
# 24  https://trees.gamemeca.com/data/monthlyrank/st...
# 25  https://trees.gamemeca.com/data/monthlyrank/st...
# 26  https://trees.gamemeca.com/data/monthlyrank/st...
# 27  https://trees.gamemeca.com/data/monthlyrank/st...
# 28  https://trees.gamemeca.com/data/monthlyrank/st...
# 29  https://trees.gamemeca.com/data/monthlyrank/st...
# 30  https://trees.gamemeca.com/data/monthlyrank/st...
# 31  https://trees.gamemeca.com/data/monthlyrank/st...
# 32  https://trees.gamemeca.com/data/monthlyrank/st...
# 33  https://trees.gamemeca.com/data/monthlyrank/st...
# 34  https://trees.gamemeca.com/data/monthlyrank/st...
# 35  https://trees.gamemeca.com/data/monthlyrank/st...
# 36  https://trees.gamemeca.com/data/monthlyrank/st...
# 37  https://trees.gamemeca.com/data/monthlyrank/st...
# 38  https://trees.gamemeca.com/data/monthlyrank/st...
# 39  https://trees.gamemeca.com/data/monthlyrank/st...
#
#                                              column-3  \
# 0                       PLAYERUNKNOWN'S BATTLEGROUNDS
# 1                                      Stardew Valley
# 2                                  Grand Theft Auto V
# 3                        ONE PIECE: PIRATE WARRIORS 4
# 4                                        DOOM Eternal
# 5                               ARK: Survival Evolved
# 6                                               삼국지14
# 7                               Red Dead Redemption 2
# 8                       Ori and the Will of the Wisps
# 9                                           Undertale
# 10                                         The Forest
# 11                                            하우스 플리퍼
# 12                                               Raft
# 13  THE WITCHER 3: WILD HUNT - GAME OF THE YEAR ED...
# 14                     Monster Hunter World: Iceborne
# 15                                           Terraria
# 16                        Assassin's Creed® Syndicate
# 17                                    DARK SOULS™ III
# 18                                   Dead by Daylight
# 19                                             썸썸 편의점
# 20                                          Jump King
# 21                              Football Manager 2020
# 22                  HALO: THE MASTER CHIEF COLLECTION
# 23       Total War: THREE KINGDOMS - A World Betrayed
# 24                             Viscera Cleanup Detail
# 25                              Don't Starve Together
# 26                           Granblue Fantasy: Versus
# 27                                   Wallpaper Engine
# 28                                Call of Duty®: WWII
# 29                                         Far Cry® 5
# 30                          Assassin's Creed® Origins
# 31                                      7 Days to Die
# 32                                         Planet Zoo
# 33                DARKEST DUNGEON®: ANCESTRAL EDITION
# 34                                  스타워즈 제다이: 오더의 몰락™
# 35                                            Forager
# 36                                      Left 4 Dead 2
# 37                                 RimWorld - Royalty
# 38                                 OCTOPATH TRAVELER™
# 39                          Citadel: Forged with Fire
#
#                                         column-3 href  \
# 0             https://trees.gamemeca.com/battleground
# 1           https://trees.gamemeca.com/stardew_valley
# 2       https://trees.gamemeca.com/grand_theft_auto_v
# 3                                                 NaN
# 4              https://trees.gamemeca.com/doometernal
# 5     https://trees.gamemeca.com/ark_survival_evolved
# 6   https://trees.gamemeca.com/romance_of_the_thre...
# 7       https://trees.gamemeca.com/reddeadredemption2
# 8   https://trees.gamemeca.com/ori_and_the_blind_f...
# 9                                                 NaN
# 10              https://trees.gamemeca.com/the_forest
# 11           https://trees.gamemeca.com/house_flipper
# 12                    https://trees.gamemeca.com/Raft
# 13  https://trees.gamemeca.com/The_Witcher_3_Wild_...
# 14    https://trees.gamemeca.com/monster_hunter_world
# 15                https://trees.gamemeca.com/Terraria
# 16                                                NaN
# 17            https://trees.gamemeca.com/dark_souls_3
# 18        https://trees.gamemeca.com/Dead_by_Daylight
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  https://trees.gamemeca.com/Viscera_Cleanup_Detail
# 25    https://trees.gamemeca.com/Dont_Starve_Together
# 26                                                NaN
# 27        https://trees.gamemeca.com/Wallpaper_Engine
# 28                                                NaN
# 29               https://trees.gamemeca.com/Far_Cry_5
# 30                                                NaN
# 31           https://trees.gamemeca.com/7_Days_to_Die
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                                           column-4 column-5
# 0                                 PUBG Corporation      FPS
# 1                                     ConcernedApe     롤플레잉
# 2                                   Rockstar Games       액션
# 3                       BANDAI NAMCO Entertainment       액션
# 4                               Bethesda Softworks       액션
# 5                                  Studio Wildcard     어드벤처
# 6                       KOEI TECMO GAMES CO., LTD.       전략
# 7                                   Rockstar Games     어드벤처
# 8                                Xbox Game Studios       액션
# 9                                          tobyfox     롤플레잉
# 10                              Endnight Games Ltd       액션
# 11                   Frozen District, PlayWay S.A.    시뮬레이션
# 12                                    Axolot Games     어드벤처
# 13                                  CD PROJEKT RED     롤플레잉
# 14                                CAPCOM Co., Ltd.       액션
# 15                                        Re-Logic     롤플레잉
# 16                                         Ubisoft       액션
# 17  FromSoftware, Inc., BANDAI NAMCO Entertainment     롤플레잉
# 18                          Behaviour Digital Inc.       액션
# 19                             TALESSHOP Co., Ltd.     어드벤처
# 20                                          Nexile     어드벤처
# 21                                            SEGA    시뮬레이션
# 22                               Xbox Game Studios      FPS
# 23                                            SEGA       전략
# 24                                       RuneStorm    시뮬레이션
# 25                              Klei Entertainment     어드벤처
# 26                XSEED Games, Marvelous USA, Inc.       액션
# 27                           Wallpaper Engine Team     유틸리티
# 28                                      Activision      FPS
# 29                                         Ubisoft       액션
# 30                                         Ubisoft       액션
# 31                 The Fun Pimps Entertainment LLC     어드벤처
# 32                           Frontier Developments    시뮬레이션
# 33                                Red Hook Studios     롤플레잉
# 34                                 Electronic Arts       액션
# 35                                   Humble Bundle     어드벤처
# 36                                           Valve      FPS
# 37                                  Ludeon Studios       전략
# 38                                     Square Enix     롤플레잉
# 39                            Blue Isle Publishing     롤플레잉

# %%
mobile[74]
# Out:
# 'mobile_202003_3.csv'

# %%
file = mobile[76]
df1 = pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
df1
# Out:
#     column-1 column-1 2                                      column-2 href  \
# 0          1        (-)                      https://trees.gamemeca.com/a3
# 1          2      (+17)                  https://trees.gamemeca.com/league
# 2          3       (-1)             https://trees.gamemeca.com/lineage2m19
# 3          4       (+1)                https://trees.gamemeca.com/terahero
# 4          5       (-1)                  https://trees.gamemeca.com/roblox
# 5          6       (-3)                https://trees.gamemeca.com/hgame_gp
# 6          7       (-1)              https://trees.gamemeca.com/brawlstars
# 7          8       (+6)                   https://trees.gamemeca.com/aooni
# 8          9       (-1)              https://trees.gamemeca.com/lineagem19
# 9         10        (-)                    https://trees.gamemeca.com/v4kr
# 10        11        (-)               https://trees.gamemeca.com/moonlight
# 11        12       (-5)             https://trees.gamemeca.com/chaosmobile
# 12        13       (-1)            https://trees.gamemeca.com/blackdesertm
# 13        14       (-1)             https://trees.gamemeca.com/counterside
# 14        15        (-)                  https://trees.gamemeca.com/maplem
# 15        16        (-)                     https://trees.gamemeca.com/rok
# 16        17        (-)                 https://trees.gamemeca.com/battlem
# 17        18        (-)              https://trees.gamemeca.com/kofallstar
# 18        19       (+1)             https://trees.gamemeca.com/sevenguilty
# 19        20      (-11)                  https://trees.gamemeca.com/smdlkr
# 20        21       (+1)               https://trees.gamemeca.com/pokemongo
# 21        22       (+2)               https://trees.gamemeca.com/lineageii
# 22        23       (-2)               https://trees.gamemeca.com/arknights
# 23        24      (NEW)            https://trees.gamemeca.com/lordofheroes
# 24        25       (-2)               https://trees.gamemeca.com/royaldice
# 25        26        (-)                https://trees.gamemeca.com/sknights
# 26        27       (-2)                  https://trees.gamemeca.com/bnsmkr
# 27        28        (-)                     https://trees.gamemeca.com/id5
# 28        29        (-)              https://trees.gamemeca.com/lastorigin
# 29        30       (+1)        https://trees.gamemeca.com/modoomarblekakao
# 30        31       (-4)             https://trees.gamemeca.com/clashroyale
# 31        32       (-2)                    https://trees.gamemeca.com/kbo3
# 32        33       (+1)            https://trees.gamemeca.com/clashofclans
# 33        34       (-2)                    https://trees.gamemeca.com/exos
# 34        35       (-2)              https://trees.gamemeca.com/langrisser
# 35        36       (-1)                https://trees.gamemeca.com/goldenkr
# 36        37      (NEW)         https://trees.gamemeca.com/princessconnect
# 37        38       (-2)  https://trees.gamemeca.com/onepiecetresurecrui...
# 38        39      (NEW)                 https://trees.gamemeca.com/archero
# 39        40       (-3)            https://trees.gamemeca.com/battlecatskr
#
#                                           rankimg src           column-3  \
# 0   https://trees.gamemeca.com/data/monthlyrank/mo...         A3: 스틸얼라이브
# 1   https://trees.gamemeca.com/data/monthlyrank/mo...           전략적 팀 전투
# 2   https://trees.gamemeca.com/data/monthlyrank/mo...              리니지2M
# 3   https://trees.gamemeca.com/data/monthlyrank/mo...             테라 히어로
# 4   https://trees.gamemeca.com/data/monthlyrank/mo...             ROBLOX
# 5   https://trees.gamemeca.com/data/monthlyrank/mo...            AFK 아레나
# 6   https://trees.gamemeca.com/data/monthlyrank/mo...              브롤스타즈
# 7   https://trees.gamemeca.com/data/monthlyrank/mo...             좀비고등학교
# 8   https://trees.gamemeca.com/data/monthlyrank/mo...               리니지M
# 9   https://trees.gamemeca.com/data/monthlyrank/mo...                 V4
# 10  https://trees.gamemeca.com/data/monthlyrank/mo...              달빛조각사
# 11  https://trees.gamemeca.com/data/monthlyrank/mo...             카오스모바일
# 12  https://trees.gamemeca.com/data/monthlyrank/mo...           검은사막 모바일
# 13  https://trees.gamemeca.com/data/monthlyrank/mo...             카운터사이드
# 14  https://trees.gamemeca.com/data/monthlyrank/mo...            메이플스토리M
# 15  https://trees.gamemeca.com/data/monthlyrank/mo...         라이즈 오브 킹덤즈
# 16  https://trees.gamemeca.com/data/monthlyrank/mo...         배틀그라운드 모바일
# 17  https://trees.gamemeca.com/data/monthlyrank/mo...    더 킹 오브 파이터즈 올스타
# 18  https://trees.gamemeca.com/data/monthlyrank/mo...   일곱개의 대죄: 그랜드 크로스
# 19  https://trees.gamemeca.com/data/monthlyrank/mo...                 R5
# 20  https://trees.gamemeca.com/data/monthlyrank/mo...               포켓몬고
# 21  https://trees.gamemeca.com/data/monthlyrank/mo...          리니지2 레볼루션
# 22  https://trees.gamemeca.com/data/monthlyrank/mo...               명일방주
# 23  https://trees.gamemeca.com/data/monthlyrank/mo...         로드 오브 히어로즈
# 24  https://trees.gamemeca.com/data/monthlyrank/mo...             랜덤 다이스
# 25  https://trees.gamemeca.com/data/monthlyrank/mo...    세븐나이츠 for kakao
# 26  https://trees.gamemeca.com/data/monthlyrank/mo...       블레이드&소울 레볼루션
# 27  https://trees.gamemeca.com/data/monthlyrank/mo...               제5인격
# 28  https://trees.gamemeca.com/data/monthlyrank/mo...             라스트오리진
# 29  https://trees.gamemeca.com/data/monthlyrank/mo...    모두의마블 for kakao
# 30  https://trees.gamemeca.com/data/monthlyrank/mo...             클래시 로얄
# 31  https://trees.gamemeca.com/data/monthlyrank/mo...              이사만루3
# 32  https://trees.gamemeca.com/data/monthlyrank/mo...          클래시 오브 클랜
# 33  https://trees.gamemeca.com/data/monthlyrank/mo...           엑소스 히어로즈
# 34  https://trees.gamemeca.com/data/monthlyrank/mo...               랑그릿사
# 35  https://trees.gamemeca.com/data/monthlyrank/mo...               리치리치
# 36  https://trees.gamemeca.com/data/monthlyrank/mo...  프린세스 커넥트! Re:Dive
# 37  https://trees.gamemeca.com/data/monthlyrank/mo...        원피스 트레저 크루즈
# 38  https://trees.gamemeca.com/data/monthlyrank/mo...             궁수의 전설
# 39  https://trees.gamemeca.com/data/monthlyrank/mo...             냥코 대전쟁
#
#                            column-4 column-5
# 0                         Netmarble     롤플레잉
# 1                   Riot Games, Inc       전략
# 2                NCSOFT Corporation     롤플레잉
# 3            Red Sahara Studio Inc.     롤플레잉
# 4                Roblox Corporation     어드벤처
# 5                      Lilith Games     롤플레잉
# 6                         Supercell       액션
# 7                      AWESOMEPIECE     아케이드
# 8                NCSOFT Corporation     롤플레잉
# 9                     NEXON Company     롤플레잉
# 10                Kakao Games Corp.     롤플레잉
# 11                        (주)엑스엔게임즈     롤플레잉
# 12                      PEARL ABYSS     롤플레잉
# 13                    NEXON Company     롤플레잉
# 14                    NEXON Company     롤플레잉
# 15                     Lilith Games       전략
# 16                 PUBG CORPORATION       액션
# 17                        Netmarble     롤플레잉
# 18                        Netmarble     롤플레잉
# 19      YOOZOO GAMES KOREA CO.,LTD.     롤플레잉
# 20                    Niantic, Inc.     어드벤처
# 21                        Netmarble     롤플레잉
# 22                  Yostar Limited.       전략
# 23             Clover Games Co.,Ltd     롤플레잉
# 24                        royaldice       전략
# 25                        Netmarble     롤플레잉
# 26                        Netmarble     롤플레잉
# 27                      X.D. Global     어드벤처
# 28                        smart joy     롤플레잉
# 29                        Netmarble       보드
# 30                        Supercell       전략
# 31                  GONGGAMES Corp.      스포츠
# 32                        Supercell       전략
# 33                       LINE Games     롤플레잉
# 34                       ZlongGames       전략
# 35                       U.LU Games    시뮬레이션
# 36                Kakao Games Corp.     롤플레잉
# 37  BANDAI NAMCO Entertainment Inc.     롤플레잉
# 38                            Habby       액션
# 39                PONOS Corporation   캐주얼 게임

# %%
file = pc[77]
df1 = pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
df1
# Out:
#     column-1 column-1 2       column-2  \
# 0          1        (-)      리그 오브 레전드
# 1          2        (-)         메이플스토리
# 2          3        (-)         피파온라인4
# 3          4        (-)         배틀그라운드
# 4          5        (-)           서든어택
# 5          6        (-)         마인크래프트
# 6          7        (-)         던전앤파이터
# 7          8        (-)          카트라이더
# 8          9        (-)           오버워치
# 9         10        (-)          로스트아크
# 10        11        (-)          아키에이지
# 11        12        (-)       천하제일상 거상
# 12        13        (-)          테일즈런너
# 13        14        (-)           사이퍼즈
# 14        15       (+2)            리니지
# 15        16       (-1)      패스 오브 엑자일
# 16        17       (-1)           검은사막
# 17        18        (-)  크레이지 아케이드 비엔비
# 18        19        (-)        블레이드앤소울
# 19        20       (+1)     아이온: 영원의 탑
# 20        21       (-1)  스타크래프트: 브루드 워
# 21        22        (-)    월드 오브 워크래프트
# 22        23       (+1)          바람의나라
# 23        24       (+1)           마비노기
# 24        25       (+1)     파이널 판타지 14
# 25        26       (+3)           하스스톤
# 26        27       (-4)          디아블로3
# 27        28       (-1)            엘소드
# 28        29       (-1)             테라
# 29        30        (-)       마비노기 영웅전
# 30        31        (-)           리니지2
# 31        32        (-)          포트나이트
# 32        33        (-)            라테일
# 33        34        (-)          스페셜포스
# 34        35        (-)          로스트사가
# 35        36       (+1)          버블파이터
# 36        37       (+3)     레전드 오브 룬테라
# 37        38       (-2)           소울워커
# 38        39       (-1)     트리 오브 세이비어
# 39        40       (-1)          테일즈위버
#
#                                     column-2 href         column-3  \
# 0      https://trees.gamemeca.com/leagueoflegends          라이엇 게임즈
# 1           https://trees.gamemeca.com/maplestory           ㈜넥슨코리아
# 2          https://trees.gamemeca.com/fifaonline4           ㈜넥슨코리아
# 3         https://trees.gamemeca.com/battleground   펍지주식회사, 카카오게임즈
# 4         https://trees.gamemeca.com/suddenattack           ㈜넥슨코리아
# 5            https://trees.gamemeca.com/minecraft     엑스박스 게임 스튜디오
# 6                   https://trees.gamemeca.com/df           ㈜넥슨코리아
# 7            https://trees.gamemeca.com/kartrider           ㈜넥슨코리아
# 8        https://trees.gamemeca.com/playoverwatch      블리자드 엔터테인먼트
# 9              https://trees.gamemeca.com/lostark       ㈜스마일게이트알피지
# 10          https://trees.gamemeca.com/archeageon          ㈜엑스엘게임즈
# 11             https://trees.gamemeca.com/gersang       ㈜에이케이인터렉티브
# 12         https://trees.gamemeca.com/talesrunner      ㈜스마일게이트메가포트
# 13             https://trees.gamemeca.com/cyphers           ㈜넥슨코리아
# 14           https://trees.gamemeca.com/lineageon           ㈜엔씨소프트
# 15                 https://trees.gamemeca.com/poe          ㈜카카오게임즈
# 16        https://trees.gamemeca.com/black_desert            ㈜펄어비스
# 17               https://trees.gamemeca.com/cabnb           ㈜넥슨코리아
# 18                 https://trees.gamemeca.com/bns           ㈜엔씨소프트
# 19                https://trees.gamemeca.com/aion           ㈜엔씨소프트
# 20        https://trees.gamemeca.com/starcraft_bw  블리자드 엔터테인먼트 코리아
# 21                 https://trees.gamemeca.com/wow  블리자드 엔터테인먼트 코리아
# 22               https://trees.gamemeca.com/baram           ㈜넥슨코리아
# 23            https://trees.gamemeca.com/mabinogi           ㈜넥슨코리아
# 24                https://trees.gamemeca.com/ff14          ㈜액토즈소프트
# 25         https://trees.gamemeca.com/hearthstone      블리자드 엔터테인먼트
# 26             https://trees.gamemeca.com/diablo3  블리자드 엔터테인먼트 코리아
# 27             https://trees.gamemeca.com/elsword           ㈜넥슨코리아
# 28              https://trees.gamemeca.com/teraon           ㈜넥슨코리아
# 29     https://trees.gamemeca.com/mabinogi_heroes           ㈜넥슨코리아
# 30         https://trees.gamemeca.com/lineageonii           ㈜엔씨소프트
# 31            https://trees.gamemeca.com/fortnite            에픽게임즈
# 32            https://trees.gamemeca.com/latalepc          ㈜액토즈소프트
# 33        https://trees.gamemeca.com/specialforce          ㈜드래곤플라이
# 34            https://trees.gamemeca.com/lostsaga            ㈜위메이드
# 35                  https://trees.gamemeca.com/bf           ㈜넥슨코리아
# 36  https://trees.gamemeca.com/legendsofruneterra          라이엇 게임즈
# 37          https://trees.gamemeca.com/soulworker      ㈜스마일게이트메가포트
# 38        https://trees.gamemeca.com/treeofsavior           ㈜넥슨코리아
# 39         https://trees.gamemeca.com/talesewaver           ㈜넥슨코리아
#
#            column-4
# 0              MOBA
# 1            MMORPG
# 2               스포츠
# 3           서바이벌 슈팅
# 4               FPS
# 5              샌드박스
# 6     벨트 스크롤 액션 RPG
# 7               레이싱
# 8           팀 기반 슈팅
# 9      핵앤슬래시 MMORPG
# 10          판타지 RPG
# 11           MMORPG
# 12              레이싱
# 13               액션
# 14           MMORPG
# 15             ARPG
# 16           MMORPG
# 17             아케이드
# 18           MMORPG
# 19           MMORPG
# 20              RTS
# 21           MMORPG
# 22           MMORPG
# 23           MMORPG
# 24           MMORPG
# 25              CCG
# 26             롤플레잉
# 27   횡스크롤 액션 MMORPG
# 28           MMORPG
# 29           액션 RPG
# 30           MMORPG
# 31     빌딩 서바이벌 배틀로얄
# 32   횡스크롤 액션 MMORPG
# 33              FPS
# 34               액션
# 35          캐주얼 TPS
# 36            카드 전략
# 37           액션 RPG
# 38           MMORPG
# 39  드라마틱 온라인 액션 RPG

# %%
df_pic_all = pd.DataFrame()
for i in range(11, 76 + 1):
    file = mobile[i] #슬레시 위치 정확하게 할 것!!
    df_pic= pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
    df_pic_all = pd.concat([df_pic_all, df_pic])

# %%
df_pic_all
# Out:
#     column-1 column-1 2                               column-2 href  \
# 0          1        (-)           https://trees.gamemeca.com/bnsmkr
# 1          2        (-)       https://trees.gamemeca.com/lineagem19
# 2          3        (-)       https://trees.gamemeca.com/brawlstars
# 3          4       (+2)           https://trees.gamemeca.com/oakwar
# 4          5       (-1)        https://trees.gamemeca.com/lineageii
# ..       ...        ...                                         ...
# 35        36       (+1)  https://trees.gamemeca.com/princessconnect
# 36        37       (-1)         https://trees.gamemeca.com/goldenkr
# 37        38      (NEW)          https://trees.gamemeca.com/rom_aos
# 38        39       (-4)       https://trees.gamemeca.com/langrisser
# 39        40       (-6)             https://trees.gamemeca.com/exos
#
#                                           rankimg src           column-3  \
# 0   https://trees.gamemeca.com/data/monthlyrank/mo...       블레이드&소울 레볼루션
# 1   https://trees.gamemeca.com/data/monthlyrank/mo...               리니지M
# 2   https://trees.gamemeca.com/data/monthlyrank/mo...              브롤스타즈
# 3   https://trees.gamemeca.com/data/monthlyrank/mo...         오크: 전쟁의 서막
# 4   https://trees.gamemeca.com/data/monthlyrank/mo...          리니지2 레볼루션
# ..                                                ...                ...
# 35  https://trees.gamemeca.com/data/monthlyrank/mo...  프린세스 커넥트! Re:Dive
# 36  https://trees.gamemeca.com/data/monthlyrank/mo...               리치리치
# 37  https://trees.gamemeca.com/data/monthlyrank/mo...             에오스 레드
# 38  https://trees.gamemeca.com/data/monthlyrank/mo...               랑그릿사
# 39  https://trees.gamemeca.com/data/monthlyrank/mo...           엑소스 히어로즈
#
#               column-4 column-5
# 0            Netmarble     롤플레잉
# 1   NCSOFT Corporation     롤플레잉
# 2            Supercell       액션
# 3         EFUN COMPANY     롤플레잉
# 4      Netmarble Games     롤플레잉
# ..                 ...      ...
# 35   Kakao Games Corp.     롤플레잉
# 36          U.LU Games    시뮬레이션
# 37    BluePotion Games     롤플레잉
# 38          ZlongGames       전략
# 39          LINE Games     롤플레잉
#
# [2330 rows x 7 columns]

# %%
df_nonpic_all = pd.DataFrame()
for i in range(77, 196 + 1):
    file = mobile[i] #슬레시 위치 정확하게 할 것!!
    df_nonpic= pd.read_csv(f'./game_crawling/{file}',encoding='utf-8')
    df_nonpic_all = pd.concat([df_nonpic_all, df_nonpic])

# %%
df_nonpic_all = df_nonpic_all[['column-1', 'column-1 2', 'column-2', 'column-3', 'column-4']]

# %%
df_nonpic_all
# Out:
#     column-1 column-1 2            column-2            column-3 column-4
# 0          1       (+1)            전략적 팀 전투     Riot Games, Inc       전략
# 1          2       (-1)          A3: 스틸얼라이브           Netmarble     롤플레잉
# 2          3        (-)               리니지2M  NCSOFT Corporation     롤플레잉
# 3          4        (-)              ROBLOX  Roblox Corporation     어드벤처
# 4          5        (-)             블레스 모바일       JOYCITY Corp.     롤플레잉
# ..       ...        ...                 ...                 ...      ...
# 35        36       (+2)  리그 오브 레전드: 와일드 리프트     Riot Games, Inc       전략
# 36        37        (-)    일곱개의 대죄: 그랜드 크로스           Netmarble     롤플레잉
# 37        38       (+2)            블레이드 키우기             mobirix    시뮬레이션
# 38        39        (-)          라이즈 오브 킹덤즈        Lilith Games       전략
# 39        40      (-17)               이터널트리            BILIBILI     롤플레잉
#
# [4800 rows x 5 columns]

# %%
df_pic_all = df_pic_all[['column-1', 'column-1 2', 'column-3', 'column-4', 'column-5']]

# %%
df_pic_all
# Out:
#     column-1 column-1 2    column-3       column-4         column-5
# 0          1        (-)       로스트아크   스마일게이트 STOVE           MMORPG
# 1          2        (-)   리그 오브 레전드        라이엇 게임즈              AOS
# 2          3        (-)      피파온라인4  NEXON COMPANY              스포츠
# 3          4        (-)      메이플스토리         넥슨 코리아             롤플레잉
# 4          5        (-)       카트라이더  NEXON COMPANY           자동차 경주
# ..       ...        ...         ...            ...              ...
# 35        36        (-)        소울워커    ㈜스마일게이트메가포트           액션 RPG
# 36        37        (-)       버블파이터         ㈜넥슨코리아          캐주얼 TPS
# 37        38       (+2)  트리 오브 세이비어         ㈜넥슨코리아           MMORPG
# 38        39       (-1)       테일즈위버         ㈜넥슨코리아  드라마틱 온라인 액션 RPG
# 39        40      (NEW)  레전드 오브 룬테라        라이엇 게임즈            카드 전략
#
# [2330 rows x 5 columns]

# %%
df_nonpic_all
# Out:
#     column-1 column-1 2                        column-2  \
# 0          1        (-)                 플레이어언노운스 배틀그라운드
# 1          2        (-)  히트맨 - GAME OF THE YEAR EDITION
# 2          3        (-)                           스타듀밸리
# 3          4        (-)                            GTA5
# 4          5        (-)                     원피스: 해적무쌍 4
# ..       ...        ...                             ...
# 35        36       (+4)                           V 라이징
# 36        37       (-1)                         그랜드 체이스
# 37        38        (-)                             문명6
# 38        39        (-)                           삼국지14
# 39        40       (-6)                다잉 라이트 2: 스테이 휴먼
#
#                                         column-2 href  \
# 0             https://trees.gamemeca.com/battleground
# 1                                                 NaN
# 2           https://trees.gamemeca.com/stardew_valley
# 3       https://trees.gamemeca.com/grand_theft_auto_v
# 4                                                 NaN
# ..                                                ...
# 35                                                NaN
# 36                       https://trees.gamemeca.com/0
# 37  https://trees.gamemeca.com/sid_meiers_civiliza...
# 38                                                NaN
# 39                                                NaN
#
#                       column-3   column-4
# 0             PUBG Corporation        FPS
# 1           Io-Interactive A/S         액션
# 2                 ConcernedApe       롤플레잉
# 3               Rockstar Games         액션
# 4   BANDAI NAMCO Entertainment         액션
# ..                         ...        ...
# 35            Stunlock Studios  오픈월드 서바이벌
# 36                         KOG        RPG
# 37                          2K      턴제 전략
# 38  KOEI TECMO GAMES CO., LTD.      시뮬레이션
# 39                    Techland         액션
#
# [4800 rows x 6 columns]

# %%
df_pic_all.rename(columns = {'column-3' : 'column-2'}, inplace = True)
df_pic_all.rename(columns = {'column-4' : 'column-3'}, inplace = True)
df_pic_all.rename(columns = {'column-5' : 'column-4'}, inplace = True)
# Out:
# C:\Users\haknyan\AppData\Local\Temp\ipykernel_19376\453666154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pic_all.rename(columns = {'column-3' : 'column-2'}, inplace = True)
# C:\Users\haknyan\AppData\Local\Temp\ipykernel_19376\453666154.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pic_all.rename(columns = {'column-4' : 'column-3'}, inplace = True)
# C:\Users\haknyan\AppData\Local\Temp\ipykernel_19376\453666154.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pic_all.rename(columns = {'column-5' : 'column-4'}, inplace = True)

# %%
df_pic_all
# Out:
#     column-1 column-1 2    column-2       column-3         column-4
# 0          1        (-)       로스트아크   스마일게이트 STOVE           MMORPG
# 1          2        (-)   리그 오브 레전드        라이엇 게임즈              AOS
# 2          3        (-)      피파온라인4  NEXON COMPANY              스포츠
# 3          4        (-)      메이플스토리         넥슨 코리아             롤플레잉
# 4          5        (-)       카트라이더  NEXON COMPANY           자동차 경주
# ..       ...        ...         ...            ...              ...
# 35        36        (-)        소울워커    ㈜스마일게이트메가포트           액션 RPG
# 36        37        (-)       버블파이터         ㈜넥슨코리아          캐주얼 TPS
# 37        38       (+2)  트리 오브 세이비어         ㈜넥슨코리아           MMORPG
# 38        39       (-1)       테일즈위버         ㈜넥슨코리아  드라마틱 온라인 액션 RPG
# 39        40      (NEW)  레전드 오브 룬테라        라이엇 게임즈            카드 전략
#
# [2330 rows x 5 columns]

# %%
df_nonpic_all
# Out:
#     column-1 column-1 2      column-2         column-3         column-4
# 0          1        (-)     리그 오브 레전드          라이엇 게임즈             MOBA
# 1          2        (-)        메이플스토리           ㈜넥슨코리아           MMORPG
# 2          3        (-)        피파온라인4           ㈜넥슨코리아              스포츠
# 3          4        (-)        배틀그라운드   펍지주식회사, 카카오게임즈          서바이벌 슈팅
# 4          5        (-)          서든어택           ㈜넥슨코리아              FPS
# ..       ...        ...           ...              ...              ...
# 35        36       (+1)  콜 오브 듀티: 뱅가드  블리자드 엔터테인먼트 코리아              FPS
# 36        37       (-1)         테일즈위버           ㈜넥슨코리아  드라마틱 온라인 액션 RPG
# 37        38       (+2)          하스스톤      블리자드 엔터테인먼트              CCG
# 38        39        (-)            아바          (주)네오위즈          FPS/TPS
# 39        40       (-2)         포트나이트            에픽게임즈     빌딩 서바이벌 배틀로얄
#
# [4800 rows x 5 columns]

# %%
df_pic_all = df_pic_all.drop(columns=['column-2 href', 'rankimg src', 'column-3 href'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\haknyan\Documents\debbu\gameData\test.ipynb 셀 30 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/haknyan/Documents/debbu/gameData/test.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> df_pic_all = df_pic_all.drop(columns=['column-2 href', 'rankimg src', 'column-3 href'])
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['column-2 href', 'rankimg src', 'column-3 href'] not found in axis"

# %%
df_pic_all
# Out:
#     column-1 column-1 2                       column-2  \
# 0          1        NaN  PLAYERUNKNOWN'S BATTLEGROUNDS
# 1          2        NaN                 Stardew Valley
# 2          3        NaN             Grand Theft Auto V
# 3          4        NaN   ONE PIECE: PIRATE WARRIORS 4
# 4          5        NaN                   DOOM Eternal
# ..       ...        ...                            ...
# 35        36      (NEW)                마운트 앤 블레이드: 워밴드
# 36        37      (-16)                        하우스 플리퍼
# 37        38       (-9)                         다크소울 3
# 38        39      (NEW)                            헤일로
# 39        40       (-7)                    데드 바이 데이라이트
#
#                                           column-3 column-4
# 0                                 PUBG Corporation      FPS
# 1                                     ConcernedApe     롤플레잉
# 2                                   Rockstar Games       액션
# 3                       BANDAI NAMCO Entertainment       액션
# 4                               Bethesda Softworks       액션
# ..                                             ...      ...
# 35                        TaleWorlds Entertainment     롤플레잉
# 36                                 Frozen District    시뮬레이션
# 37  FromSoftware, Inc., BANDAI NAMCO Entertainment     롤플레잉
# 38                               Xbox Game Studios       액션
# 39                          Behaviour Digital Inc.       액션
#
# [120 rows x 5 columns]

# %%
df_nonpic_all = df_nonpic_all[['column-1', 'column-1 2', 'column-2', 'column-3', 'column-4']]
df_nonpic_all
# Out:
#     column-1 column-1 2                        column-2  \
# 0          1        (-)                 플레이어언노운스 배틀그라운드
# 1          2        (-)  히트맨 - GAME OF THE YEAR EDITION
# 2          3        (-)                           스타듀밸리
# 3          4        (-)                            GTA5
# 4          5        (-)                     원피스: 해적무쌍 4
# ..       ...        ...                             ...
# 35        36       (+4)                           V 라이징
# 36        37       (-1)                         그랜드 체이스
# 37        38        (-)                             문명6
# 38        39        (-)                           삼국지14
# 39        40       (-6)                다잉 라이트 2: 스테이 휴먼
#
#                       column-3   column-4
# 0             PUBG Corporation        FPS
# 1           Io-Interactive A/S         액션
# 2                 ConcernedApe       롤플레잉
# 3               Rockstar Games         액션
# 4   BANDAI NAMCO Entertainment         액션
# ..                         ...        ...
# 35            Stunlock Studios  오픈월드 서바이벌
# 36                         KOG        RPG
# 37                          2K      턴제 전략
# 38  KOEI TECMO GAMES CO., LTD.      시뮬레이션
# 39                    Techland         액션
#
# [4800 rows x 5 columns]

# %%
df_pic_all.rename(columns = {'column-3' : 'column-2'}, inplace = True)
df_pic_all.rename(columns = {'column-4' : 'column-3'}, inplace = True)
df_pic_all.rename(columns = {'column-5' : 'column-4'}, inplace = True)

# %%
df_pic_all
# Out:
#     column-1 column-1 2                       column-2  \
# 0          1        NaN  PLAYERUNKNOWN'S BATTLEGROUNDS
# 1          2        NaN                 Stardew Valley
# 2          3        NaN             Grand Theft Auto V
# 3          4        NaN   ONE PIECE: PIRATE WARRIORS 4
# 4          5        NaN                   DOOM Eternal
# ..       ...        ...                            ...
# 35        36      (-14)                    풋볼 매니저 2020
# 36        37       (-8)                  콜 오브 듀티: WWII
# 37        38      (-17)                           점프 킹
# 38        39       (-9)                         파크라이 5
# 39        40      (-19)                 디비니티: 오리지널 신 2
#
#                       column-3 column-4
# 0             PUBG Corporation      FPS
# 1                 ConcernedApe     롤플레잉
# 2               Rockstar Games       액션
# 3   BANDAI NAMCO Entertainment       액션
# 4           Bethesda Softworks       액션
# ..                         ...      ...
# 35                        SEGA    시뮬레이션
# 36                  Activision      FPS
# 37                      Nexile       액션
# 38                     Ubisoft       액션
# 39              Larian Studios     롤플레잉
#
# [80 rows x 5 columns]

# %%
df_nonpic_all
# Out:
#     column-1 column-1 2                        column-2  \
# 0          1        (-)                 플레이어언노운스 배틀그라운드
# 1          2        (-)  히트맨 - GAME OF THE YEAR EDITION
# 2          3        (-)                           스타듀밸리
# 3          4        (-)                            GTA5
# 4          5        (-)                     원피스: 해적무쌍 4
# ..       ...        ...                             ...
# 35        36       (-1)                         그랜드 체이스
# 36        37       (-7)                              쿼리
# 37        38       (-1)                             문명6
# 38        39       (-3)                           삼국지14
# 39        40       (-1)                           V 라이징
#
#                       column-3   column-4
# 0             PUBG Corporation        FPS
# 1           Io-Interactive A/S         액션
# 2                 ConcernedApe       롤플레잉
# 3               Rockstar Games         액션
# 4   BANDAI NAMCO Entertainment         액션
# ..                         ...        ...
# 35                         KOG        RPG
# 36                    2K Games    공포 어드벤처
# 37                          2K      턴제 전략
# 38  KOEI TECMO GAMES CO., LTD.      시뮬레이션
# 39            Stunlock Studios  오픈월드 서바이벌
#
# [4760 rows x 5 columns]

# %%
df_nonpic_all.drop('column-2 href', axis=1, inplace=True)
df_nonpic_all
# Out:
#     column-1 column-1 2      column-2         column-3         column-4
# 0          1        (-)     리그 오브 레전드          라이엇 게임즈             MOBA
# 1          2        (-)        메이플스토리           ㈜넥슨코리아           MMORPG
# 2          3        (-)        피파온라인4           ㈜넥슨코리아              스포츠
# 3          4        (-)        배틀그라운드   펍지주식회사, 카카오게임즈          서바이벌 슈팅
# 4          5        (-)          서든어택           ㈜넥슨코리아              FPS
# ..       ...        ...           ...              ...              ...
# 35        36       (+2)         테일즈위버           ㈜넥슨코리아  드라마틱 온라인 액션 RPG
# 36        37       (-1)  콜 오브 듀티: 뱅가드  블리자드 엔터테인먼트 코리아              FPS
# 37        38       (-1)         포트나이트            에픽게임즈     빌딩 서바이벌 배틀로얄
# 38        39        (-)            아바          (주)네오위즈          FPS/TPS
# 39        40      (NEW)          하스스톤      블리자드 엔터테인먼트              CCG
#
# [4760 rows x 5 columns]

# %%
df_all = pd.DataFrame()
df_all = pd.concat([df_pic_all, df_nonpic_all])

# %%
df_all
# Out:
#     column-1 column-1 2      column-2         column-3         column-4
# 0          1        (-)         로스트아크     스마일게이트 STOVE           MMORPG
# 1          2        (-)     리그 오브 레전드          라이엇 게임즈              AOS
# 2          3        (-)        피파온라인4    NEXON COMPANY              스포츠
# 3          4        (-)        메이플스토리           넥슨 코리아             롤플레잉
# 4          5        (-)         카트라이더    NEXON COMPANY           자동차 경주
# ..       ...        ...           ...              ...              ...
# 35        36       (+1)  콜 오브 듀티: 뱅가드  블리자드 엔터테인먼트 코리아              FPS
# 36        37       (-1)         테일즈위버           ㈜넥슨코리아  드라마틱 온라인 액션 RPG
# 37        38       (+2)          하스스톤      블리자드 엔터테인먼트              CCG
# 38        39        (-)            아바          (주)네오위즈          FPS/TPS
# 39        40       (-2)         포트나이트            에픽게임즈     빌딩 서바이벌 배틀로얄
#
# [7130 rows x 5 columns]

# %%
df_all.to_csv('./game_tree/pc_all.csv')

# %%
# 30개씩 자르는 코드
#data = pd.read_csv('C:/Users/snm03/Documents/debbu/gameData/the_log_all.csv')
#data['tablescraper-selected-row']=data['tablescraper-selected-row'].astype(int)
i = data_all[data_all['tablescraper-selected-row']>30].index
data_all_top30 = data_all.drop(i)
data_all_top30

# %%
df_pc = pd.DataFrame()
df_pc= pd.read_csv('./game_tree/pc_all.csv',encoding='utf-8')
df_pc
# Out:
#       Unnamed: 0  column-1 column-1 2      column-2         column-3  \
# 0              0         1        (-)         로스트아크     스마일게이트 STOVE
# 1              1         2        (-)     리그 오브 레전드          라이엇 게임즈
# 2              2         3        (-)        피파온라인4    NEXON COMPANY
# 3              3         4        (-)        메이플스토리           넥슨 코리아
# 4              4         5        (-)         카트라이더    NEXON COMPANY
# ...          ...       ...        ...           ...              ...
# 7045          35        36       (+2)         테일즈위버           ㈜넥슨코리아
# 7046          36        37       (-1)  콜 오브 듀티: 뱅가드  블리자드 엔터테인먼트 코리아
# 7047          37        38       (-1)         포트나이트            에픽게임즈
# 7048          38        39        (-)            아바          (주)네오위즈
# 7049          39        40      (NEW)          하스스톤      블리자드 엔터테인먼트
#
#              column-4
# 0              MMORPG
# 1                 AOS
# 2                 스포츠
# 3                롤플레잉
# 4              자동차 경주
# ...               ...
# 7045  드라마틱 온라인 액션 RPG
# 7046              FPS
# 7047     빌딩 서바이벌 배틀로얄
# 7048          FPS/TPS
# 7049              CCG
#
# [7050 rows x 6 columns]

# %%
i = df_pc[df_pc['column-1']>20].index
pc_top20 = df_pc.drop(i)
pc_top20
# Out:
#       Unnamed: 0  column-1 column-1 2   column-2       column-3 column-4
# 0              0         1        (-)      로스트아크   스마일게이트 STOVE   MMORPG
# 1              1         2        (-)  리그 오브 레전드        라이엇 게임즈      AOS
# 2              2         3        (-)     피파온라인4  NEXON COMPANY      스포츠
# 3              3         4        (-)     메이플스토리         넥슨 코리아     롤플레잉
# 4              4         5        (-)      카트라이더  NEXON COMPANY   자동차 경주
# ...          ...       ...        ...        ...            ...      ...
# 7025          15        16       (+4)       마비노기         ㈜넥슨코리아   MMORPG
# 7026          16        17       (-1)       오버워치    블리자드 엔터테인먼트  팀 기반 슈팅
# 7027          17        18       (-1)      테일즈런너    ㈜스마일게이트메가포트      레이싱
# 7028          18        19        (-)        리니지         ㈜엔씨소프트   MMORPG
# 7029          19        20       (-2)      바람의나라         ㈜넥슨코리아   MMORPG
#
# [3680 rows x 6 columns]

# %%
pc_top20.dtypes
# Out:
# Unnamed: 0     int64
# column-1       int64
# column-1 2    object
# column-2      object
# column-3      object
# column-4      object
# dtype: object

# %%
# 컬럼명 바꾸기
pc_top20.rename(columns = {'column-1':'rank'},inplace=True)
# 컬럼명 바꾸기
pc_top20.rename(columns = {'column-2':'name'},inplace=True)
# 컬럼명 바꾸기
pc_top20.rename(columns = {'column-3':'company'},inplace=True)
pc_top20.rename(columns = {'column-4':'type'},inplace=True)

# %%
pc_top20
# Out:
#       Unnamed: 0  rank column-1 2       name        company     type
# 0              0     1        (-)      로스트아크   스마일게이트 STOVE   MMORPG
# 1              1     2        (-)  리그 오브 레전드        라이엇 게임즈      AOS
# 2              2     3        (-)     피파온라인4  NEXON COMPANY      스포츠
# 3              3     4        (-)     메이플스토리         넥슨 코리아     롤플레잉
# 4              4     5        (-)      카트라이더  NEXON COMPANY   자동차 경주
# ...          ...   ...        ...        ...            ...      ...
# 7025          15    16       (+4)       마비노기         ㈜넥슨코리아   MMORPG
# 7026          16    17       (-1)       오버워치    블리자드 엔터테인먼트  팀 기반 슈팅
# 7027          17    18       (-1)      테일즈런너    ㈜스마일게이트메가포트      레이싱
# 7028          18    19        (-)        리니지         ㈜엔씨소프트   MMORPG
# 7029          19    20       (-2)      바람의나라         ㈜넥슨코리아   MMORPG
#
# [3680 rows x 6 columns]

# %%
pc_top20 = pc_top20.reset_index()

# %%
pc_top20
pc_top20.drop(columns = {'index'},inplace=True)

# %%
pc_top20
# Out:
#       Unnamed: 0  rank column-1 2       name        company     type
# 0              0     1        (-)      로스트아크   스마일게이트 STOVE   MMORPG
# 1              1     2        (-)  리그 오브 레전드        라이엇 게임즈      AOS
# 2              2     3        (-)     피파온라인4  NEXON COMPANY      스포츠
# 3              3     4        (-)     메이플스토리         넥슨 코리아     롤플레잉
# 4              4     5        (-)      카트라이더  NEXON COMPANY   자동차 경주
# ...          ...   ...        ...        ...            ...      ...
# 3675          15    16       (+4)       마비노기         ㈜넥슨코리아   MMORPG
# 3676          16    17       (-1)       오버워치    블리자드 엔터테인먼트  팀 기반 슈팅
# 3677          17    18       (-1)      테일즈런너    ㈜스마일게이트메가포트      레이싱
# 3678          18    19        (-)        리니지         ㈜엔씨소프트   MMORPG
# 3679          19    20       (-2)      바람의나라         ㈜넥슨코리아   MMORPG
#
# [3680 rows x 6 columns]

# %%
pc_top20.insert(0,"week_num",0)
pc_top20
# Out:
#       week_num  Unnamed: 0  rank column-1 2       name        company     type
# 0            0           0     1        (-)      로스트아크   스마일게이트 STOVE   MMORPG
# 1            0           1     2        (-)  리그 오브 레전드        라이엇 게임즈      AOS
# 2            0           2     3        (-)     피파온라인4  NEXON COMPANY      스포츠
# 3            0           3     4        (-)     메이플스토리         넥슨 코리아     롤플레잉
# 4            0           4     5        (-)      카트라이더  NEXON COMPANY   자동차 경주
# ...        ...         ...   ...        ...        ...            ...      ...
# 3675         0          15    16       (+4)       마비노기         ㈜넥슨코리아   MMORPG
# 3676         0          16    17       (-1)       오버워치    블리자드 엔터테인먼트  팀 기반 슈팅
# 3677         0          17    18       (-1)      테일즈런너    ㈜스마일게이트메가포트      레이싱
# 3678         0          18    19        (-)        리니지         ㈜엔씨소프트   MMORPG
# 3679         0          19    20       (-2)      바람의나라         ㈜넥슨코리아   MMORPG
#
# [3680 rows x 7 columns]

# %%
pc_top20['num'] = pc_top20.index

# %%
pc_top20.drop(columns = {'Unnamed: 0'},inplace=True)
pc_top20
# Out:
#       week_num  rank column-1 2       name        company     type   num
# 0            0     1        (-)      로스트아크   스마일게이트 STOVE   MMORPG     0
# 1            0     2        (-)  리그 오브 레전드        라이엇 게임즈      AOS     1
# 2            0     3        (-)     피파온라인4  NEXON COMPANY      스포츠     2
# 3            0     4        (-)     메이플스토리         넥슨 코리아     롤플레잉     3
# 4            0     5        (-)      카트라이더  NEXON COMPANY   자동차 경주     4
# ...        ...   ...        ...        ...            ...      ...   ...
# 3675         0    16       (+4)       마비노기         ㈜넥슨코리아   MMORPG  3675
# 3676         0    17       (-1)       오버워치    블리자드 엔터테인먼트  팀 기반 슈팅  3676
# 3677         0    18       (-1)      테일즈런너    ㈜스마일게이트메가포트      레이싱  3677
# 3678         0    19        (-)        리니지         ㈜엔씨소프트   MMORPG  3678
# 3679         0    20       (-2)      바람의나라         ㈜넥슨코리아   MMORPG  3679
#
# [3680 rows x 7 columns]

# %%
pc_top20.drop(columns = {'num'},inplace=True)
pc_top20
# Out:
#       week_num  rank column-1 2       name        company     type
# 0            0     1        (-)      로스트아크   스마일게이트 STOVE   MMORPG
# 1            0     2        (-)  리그 오브 레전드        라이엇 게임즈      AOS
# 2            0     3        (-)     피파온라인4  NEXON COMPANY      스포츠
# 3            0     4        (-)     메이플스토리         넥슨 코리아     롤플레잉
# 4            0     5        (-)      카트라이더  NEXON COMPANY   자동차 경주
# ...        ...   ...        ...        ...            ...      ...
# 3675       183    16       (+4)       마비노기         ㈜넥슨코리아   MMORPG
# 3676       183    17       (-1)       오버워치    블리자드 엔터테인먼트  팀 기반 슈팅
# 3677       183    18       (-1)      테일즈런너    ㈜스마일게이트메가포트      레이싱
# 3678       183    19        (-)        리니지         ㈜엔씨소프트   MMORPG
# 3679       183    20       (-2)      바람의나라         ㈜넥슨코리아   MMORPG
#
# [3680 rows x 6 columns]

# %%
share=pc_top20['num']//20
pc_top20['week_num']=share

# %%
pc_top20
# Out:
#       week_num  rank column-1 2       name        company     type   num
# 0            0     1        (-)      로스트아크   스마일게이트 STOVE   MMORPG     0
# 1            0     2        (-)  리그 오브 레전드        라이엇 게임즈      AOS     1
# 2            0     3        (-)     피파온라인4  NEXON COMPANY      스포츠     2
# 3            0     4        (-)     메이플스토리         넥슨 코리아     롤플레잉     3
# 4            0     5        (-)      카트라이더  NEXON COMPANY   자동차 경주     4
# ...        ...   ...        ...        ...            ...      ...   ...
# 3675       183    16       (+4)       마비노기         ㈜넥슨코리아   MMORPG  3675
# 3676       183    17       (-1)       오버워치    블리자드 엔터테인먼트  팀 기반 슈팅  3676
# 3677       183    18       (-1)      테일즈런너    ㈜스마일게이트메가포트      레이싱  3677
# 3678       183    19        (-)        리니지         ㈜엔씨소프트   MMORPG  3678
# 3679       183    20       (-2)      바람의나라         ㈜넥슨코리아   MMORPG  3679
#
# [3680 rows x 7 columns]

# %%
# 
pc_groupby = pc_top20.groupby('name')['name'].count()
pc_groupby_asc = pc_groupby.sort_values(ascending=False)
pc_groupby
# Out:
# name
# GTA5                 1
# 검은사막               118
# 더 위쳐                 2
# 던전앤파이터             184
# 도타2                  3
# 도타2 (오토체스)           4
# 디아블로2               16
# 디아블로2 레저렉션          40
# 디아블로3                1
# 라테일                  2
# 레드 데드 리뎀션2           1
# 레전드 오브 룬테라           9
# 로스트아크              184
# 리그 오브 레전드          184
# 리니지                184
# 리니지2                20
# 마비노기                33
# 마인크래프트             184
# 마인크래프트 던전스           4
# 메이플스토리             184
# 몬스터헌터 월드             3
# 바람의나라               24
# 발로란트               111
# 배틀그라운드             184
# 블레이드앤소울            121
# 사이퍼즈               184
# 삼국지14                3
# 서든어택               184
# 스타듀 밸리               1
# 스타크래프트: 브루드 워       40
# 아스텔리아                6
# 아이온                 90
# 아이온: 영원의 탑          52
# 아키에이지              178
# 에이펙스 레전드             9
# 엘리온                 20
# 엘소드                 18
# 오버워치               184
# 월드 오브 워크래프트         27
# 천하제일상 거상           184
# 카트라이더              184
# 커츠펠                  4
# 콜 오브 듀티: 모던 워페어      4
# 콜 오브 듀티: 뱅가드         4
# 크레이지 아케이드 비엔비       42
# 테라                  12
# 테일즈런너              171
# 토탈 워: 삼국             3
# 파이널 판타지 14           5
# 패스 오브 엑자일           72
# 포트나이트                4
# 폴 가이즈                1
# 폴가이즈                 2
# 피파 20                5
# 피파온라인4             184
# 하이퍼 스케이프             2
# Name: name, dtype: int64

# %%
pc_groupby_asc_df = pd.DataFrame(pc_groupby_asc, columns=['name'])
pc_groupby_asc_df
# Out:
#                  name
# name
# 사이퍼즈              184
# 로스트아크             184
# 오버워치              184
# 서든어택              184
# 배틀그라운드            184
# 카트라이더             184
# 메이플스토리            184
# 마인크래프트            184
# 리니지               184
# 리그 오브 레전드         184
# 천하제일상 거상          184
# 던전앤파이터            184
# 피파온라인4            184
# 아키에이지             178
# 테일즈런너             171
# 블레이드앤소울           121
# 검은사막              118
# 발로란트              111
# 아이온                90
# 패스 오브 엑자일          72
# 아이온: 영원의 탑         52
# 크레이지 아케이드 비엔비      42
# 디아블로2 레저렉션         40
# 스타크래프트: 브루드 워      40
# 마비노기               33
# 월드 오브 워크래프트        27
# 바람의나라              24
# 리니지2               20
# 엘리온                20
# 엘소드                18
# 디아블로2              16
# 테라                 12
# 에이펙스 레전드            9
# 레전드 오브 룬테라          9
# 아스텔리아               6
# 피파 20               5
# 파이널 판타지 14          5
# 콜 오브 듀티: 모던 워페어     4
# 커츠펠                 4
# 콜 오브 듀티: 뱅가드        4
# 포트나이트               4
# 마인크래프트 던전스          4
# 도타2 (오토체스)          4
# 삼국지14               3
# 몬스터헌터 월드            3
# 토탈 워: 삼국            3
# 도타2                 3
# 폴가이즈                2
# 라테일                 2
# 더 위쳐                2
# 하이퍼 스케이프            2
# GTA5                1
# 폴 가이즈               1
# 레드 데드 리뎀션2          1
# 디아블로3               1
# 스타듀 밸리              1

# %%
pc_top20=pc_top20.rename(columns={'Unnamed: 0':'num'})

# %%
pc_top20
# Out:
#       week_num  num  rank column-1 2       name        company     type
# 0            0    0     1        (-)      로스트아크   스마일게이트 STOVE   MMORPG
# 1            0    1     2        (-)  리그 오브 레전드        라이엇 게임즈      AOS
# 2            0    2     3        (-)     피파온라인4  NEXON COMPANY      스포츠
# 3            0    3     4        (-)     메이플스토리         넥슨 코리아     롤플레잉
# 4            0    4     5        (-)      카트라이더  NEXON COMPANY   자동차 경주
# ...        ...  ...   ...        ...        ...            ...      ...
# 7025         0   15    16       (+4)       마비노기         ㈜넥슨코리아   MMORPG
# 7026         0   16    17       (-1)       오버워치    블리자드 엔터테인먼트  팀 기반 슈팅
# 7027         0   17    18       (-1)      테일즈런너    ㈜스마일게이트메가포트      레이싱
# 7028         0   18    19        (-)        리니지         ㈜엔씨소프트   MMORPG
# 7029         0   19    20       (-2)      바람의나라         ㈜넥슨코리아   MMORPG
#
# [3680 rows x 7 columns]

# %%
share=pc_top20['num']//20
pc_top20['week_num']=share

# %%
pc_top20
# Out:
#       week_num  num  rank column-1 2       name        company     type
# 0            0    0     1        (-)      로스트아크   스마일게이트 STOVE   MMORPG
# 1            0    1     2        (-)  리그 오브 레전드        라이엇 게임즈      AOS
# 2            0    2     3        (-)     피파온라인4  NEXON COMPANY      스포츠
# 3            0    3     4        (-)     메이플스토리         넥슨 코리아     롤플레잉
# 4            0    4     5        (-)      카트라이더  NEXON COMPANY   자동차 경주
# ...        ...  ...   ...        ...        ...            ...      ...
# 7025         0   15    16       (+4)       마비노기         ㈜넥슨코리아   MMORPG
# 7026         0   16    17       (-1)       오버워치    블리자드 엔터테인먼트  팀 기반 슈팅
# 7027         0   17    18       (-1)      테일즈런너    ㈜스마일게이트메가포트      레이싱
# 7028         0   18    19        (-)        리니지         ㈜엔씨소프트   MMORPG
# 7029         0   19    20       (-2)      바람의나라         ㈜넥슨코리아   MMORPG
#
# [3680 rows x 7 columns]

# %%
bg=pc_top20.loc[pc_top20['name']=='카트라이더']

# %%
plt.plot(bg['week_num'],bg['rank'])

# %%
pc_top20.head(6)
# Out:
#    week_num  rank column-1 2       name                  company    type
# 0         0     1        (-)      로스트아크             스마일게이트 STOVE  MMORPG
# 1         0     2        (-)  리그 오브 레전드                  라이엇 게임즈     AOS
# 2         0     3        (-)     피파온라인4            NEXON COMPANY     스포츠
# 3         0     4        (-)     메이플스토리                   넥슨 코리아    롤플레잉
# 4         0     5        (-)      카트라이더            NEXON COMPANY  자동차 경주
# 5         0     6        (-)     배틀그라운드  KAKAO GAMES CORP., PUBG     FPS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.io.json import json_normalize
import os
import openpyxl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\haknyan\Documents\debbu\gameData\test.ipynb 셀 67 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/haknyan/Documents/debbu/gameData/test.ipynb#Y125sZmlsZQ%3D%3D?line=4'>5</a> from pandas.io.json import json_normalize
#       <a href='vscode-notebook-cell:/c%3A/Users/haknyan/Documents/debbu/gameData/test.ipynb#Y125sZmlsZQ%3D%3D?line=5'>6</a> import os
# ----> <a href='vscode-notebook-cell:/c%3A/Users/haknyan/Documents/debbu/gameData/test.ipynb#Y125sZmlsZQ%3D%3D?line=6'>7</a> import openpyxl
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
note = pd.read_csv('./update_note.csv',encoding='utf-8')
note
# Out:
#     Unnamed: 0         date  read  thumb
# 0            0  2022.08.03.  2.3만     26
# 1            1  2022.07.06.  2.7만     31
# 2            2  2022.05.31.  3.1만     21
# 3            3  2022.05.03.    4만     25
# 4            4  2022.04.06.  3.7만     48
# ..         ...          ...   ...    ...
# 68          68  2018.01.30.  9.4만     34
# 69          69  2018.01.24.  9.2만     35
# 70          70  2018.01.09.   14만     80
# 71          71  2017.12.28.  7.6만     42
# 72          72  2017.12.21.   13만    113
#
# [73 rows x 4 columns]

# %%
df_article = pd.read_excel("./article/hack_article_final.xlsx")
df_article[['일자','제목']]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     137 try:
# --> 138     module = importlib.import_module(name)
#     139 except ImportError:
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\haknyan\Documents\debbu\gameData\test.ipynb 셀 68 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/haknyan/Documents/debbu/gameData/test.ipynb#Y124sZmlsZQ%3D%3D?line=0'>1</a> df_article = pd.read_excel("./article/hack_article_final.xlsx")
#       <a href='vscode-notebook-cell:/c%3A/Users/haknyan/Documents/debbu/gameData/test.ipynb#Y124sZmlsZQ%3D%3D?line=1'>2</a> df_article[['일자','제목']]
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\io\excel\_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\io\excel\_base.py:1419, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1416 self.engine = engine
#    1417 self.storage_options = storage_options
# -> 1419 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\io\excel\_openpyxl.py:524, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     509 def __init__(
#     510     self,
#     511     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#     512     storage_options: StorageOptions = None,
#     513 ) -> None:
#     514     """
#     515     Reader using openpyxl engine.
#     516
#    (...)
#     522         passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     523     """
# --> 524     import_optional_dependency("openpyxl")
#     525     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\haknyan\miniconda3\envs\debbu\lib\site-packages\pandas\compat\_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     139 except ImportError:
#     140     if errors == "raise":
# --> 141         raise ImportError(msg)
#     142     else:
#     143         return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
