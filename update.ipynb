# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
note = pd.read_csv('./pretty_update.csv',encoding='utf-8')
note['date'] = note['date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m'))
note
# Out:
#          date  개수
# 0  2017-12-01   2
# 1  2018-01-01   3
# 2  2018-02-01   2
# 3  2018-03-01   2
# 4  2018-04-01   4
# 5  2018-05-01   2
# 6  2018-06-01   3
# 7  2018-07-01   3
# 8  2018-08-01   2
# 9  2018-09-01   2
# 10 2018-10-01   1
# 11 2018-11-01   1
# 12 2018-12-01   1
# 13 2019-01-01   2
# 14 2019-02-01   1
# 15 2019-03-01   1
# 16 2019-04-01   1
# 17 2019-05-01   1
# 18 2019-06-01   1
# 19 2019-07-01   1
# 20 2019-08-01   1
# 21 2019-09-01   1
# 22 2019-10-01   1
# 23 2019-11-01   1
# 24 2019-12-01   1
# 25 2020-01-01   1
# 26 2020-02-01   1
# 27 2020-03-01   1
# 28 2020-04-01   1
# 29 2020-05-01   1
# 30 2020-06-01   1
# 31 2020-07-01   1
# 32 2020-08-01   1
# 33 2020-09-01   1
# 34 2020-10-01   1
# 35 2020-11-01   1
# 36 2020-12-01   1
# 37 2021-01-01   1
# 38 2021-02-01   1
# 39 2021-03-01   1
# 40 2021-04-01   1
# 41 2021-05-01   1
# 42 2021-06-01   1
# 43 2021-07-01   1
# 44 2021-08-01   1
# 45 2021-09-01   1
# 46 2021-10-01   1
# 47 2021-11-01   1
# 48 2021-12-01   0
# ...

# %%
fig = plt.figure(figsize=(13,5))
ax = fig.add_subplot(1, 1, 1)
x=note['date']
y=note['개수']
plt.yticks([0, 1, 2, 3, 4])
plt.plot(x,y,color='orange')
plt.title('',size=20)
plt.title('BattleGround update note',size=20)
# Out:
# Text(0.5, 1.0, 'BattleGround update note')
