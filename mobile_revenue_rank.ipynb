# %%
url = 'https://www.mobileindex.com/api/chart/revenue_rank'
param = {'appType' : 'game',
         'dateType' : 'w',
         'date' : '20200504',
         'startRank' : '1',
         'endRank' : '200'}
header = {'referer' : 'https://www.mobileindex.com/mi-chart/weekly-rank/revenue',
          'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
         }
resp = requests.get(url, params = param,headers = header)

# %%
data = json.loads(resp.text)

# %%
df = pd.DataFrame(data['data'])
df
# Out:
#     rank  rank_change                   app_name  \
# 0      1          2.0                       리니지W
# 1      2         -1.0                       리니지M
# 2      3         -1.0                오딘: 발할라 라이징
# 3      4          1.0               우마무스메 프리티 더비
# 4      5         -1.0                   히어로즈 테일즈
# ..   ...          ...                        ...
# 95    96        -16.0                    AFK 아레나
# 96    97        -62.0                  클래시 오브 클랜
# 97    98         -5.0       에이스 디펜더: 드래곤 슬레이어 전쟁
# 98    99         -3.0  랜덤 다이스(Random Dice) : 디펜스
# 99   100         -2.0      카카오웹툰 – KAKAO WEBTOON
#
#                     publisher_name                package_name  \
# 0                           NCSOFT         com.ncsoft.lineagew
# 1                           NCSOFT       com.ncsoft.lineagem19
# 2                Kakao Games Corp.         com.kakaogames.odin
# 3                Kakao Games Corp.    com.kakaogames.umamusume
# ...

# %% [markdown]
# from selenium import webdriver ## 크롬을 자동화 시켜서 제어할 수 있는 프로그램. 셀레니움으로 컨트롤
# from selenium.webdriver.common.keys import Keys #입력키
# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager #자동설정에 필요한 함수들
# from selenium.webdriver.common.by import By # 셀렉터 도구자

# %% [markdown]
# def set_chrome_driver():
#     chrome_options = webdriver.ChromeOptions()
#     driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
#     return driver
# driver = set_chrome_driver()

# %% [markdown]
# url = 'https://www.mobileindex.com/api/chart/revenue_rank'
# header = {'referer' : 'https://www.mobileindex.com/mi-chart/weekly-rank/revenue',
#           'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
#          }
# driver.get(url)

# %%
url = 'https://www.mobileindex.com/api/chart/revenue_rank'
param = {'appType' : 'game',
         'dateType' : 'w',
         'date' : '20200511',
         'startRank' : '1',
         'endRank' : '200'}
header = {'referer' : 'https://www.mobileindex.com/mi-chart/weekly-rank/revenue',
          'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
         }
resp = requests.get(url, params = param,headers = header)

# %%
data = json.loads(resp.text)
df = pd.DataFrame(data['data'])
df
# Out:
#     rank  rank_change                   app_name  \
# 0      1          2.0                       리니지W
# 1      2         -1.0                       리니지M
# 2      3         -1.0                오딘: 발할라 라이징
# 3      4          1.0               우마무스메 프리티 더비
# 4      5         -1.0                   히어로즈 테일즈
# ..   ...          ...                        ...
# 95    96        -16.0                    AFK 아레나
# 96    97        -62.0                  클래시 오브 클랜
# 97    98         -5.0       에이스 디펜더: 드래곤 슬레이어 전쟁
# 98    99         -3.0  랜덤 다이스(Random Dice) : 디펜스
# 99   100         -2.0      카카오웹툰 – KAKAO WEBTOON
#
#                     publisher_name                package_name  \
# 0                           NCSOFT         com.ncsoft.lineagew
# 1                           NCSOFT       com.ncsoft.lineagem19
# 2                Kakao Games Corp.         com.kakaogames.odin
# 3                Kakao Games Corp.    com.kakaogames.umamusume
# ...
